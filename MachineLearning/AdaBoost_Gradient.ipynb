# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeRosique/ComputerScience/blob/main/AdaBoost_Gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AdaBoost y Gradient boosting con árboles en un dataset de detección de spam
#
# Árboles de decisión y todos los ensembles propuestos funcionan en la práctica muy bien en datos tabulares como puede ser el problema de reconocimiento de spam en mails.
#
# Se propone pues emplear el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)

# %% [markdown]
# ## AdaBoost
#
# Probemos el clasificador de AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

ab = AdaBoostClassifier()

acc=ab.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 93.8%

# %% [markdown]
# **Ejercicio** Teniendo en cuenta la documentación [AdaBoost](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html) prueba mediante grid search a encontrar mejores parámetros.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

#Crea el clasificador Adaboost
ab = AdaBoostClassifier(estimator = DecisionTreeClassifier(random_state=23))

## Grid Search
G = {"n_estimators":[20,30,40,50,100,200],
     "estimator__max_depth":[1,2,4,6,8,10]}

GS = GridSearchCV(ab, G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)
# Precisión: 95.1% con {'estimator__max_depth': 4, 'n_estimators': 200}

# %% [markdown]
# ## GradientBoostingClassifier
#
# Probemos el clasificador Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

acc=gb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 95.0%

# %% [markdown]
# Los principales parámetros del GradientBoosting son:
# * n_estimators (100)
# * max_depth (3)
# * max_features
#
# **Ejercicio** prueba diferentes valores (lógicos) de estos parámetros mediante GridSearch.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

#Crea el clasificador Adaboost
gb = GradientBoostingClassifier()

## Grid Search
G = {"n_estimators":[20,40,60,100],
     "max_depth":[4,6,8,10],
     "max_features":[0.2,0.5,0.8]}

GS = GridSearchCV(gb, G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START max_depth=4, max_features=0.2, n_estimators=20.............
# [CV 1/5; 1/48] END max_depth=4, max_features=0.2, n_estimators=20;, score=0.931 total time=   0.1s
# [CV 2/5; 1/48] START max_depth=4, max_features=0.2, n_estimators=20.............
# [CV 2/5; 1/48] END max_depth=4, max_features=0.2, n_estimators=20;, score=0.921 total time=   0.1s
# [CV 3/5; 1/48] START max_depth=4, max_features=0.2, n_estimators=20.............
# [CV 3/5; 1/48] END max_depth=4, max_features=0.2, n_estimators=20;, score=0.936 total time=   0.1s
# [CV 4/5; 1/48] START max_depth=4, max_features=0.2, n_estimators=20.............
# [CV 4/5; 1/48] END max_depth=4, max_features=0.2, n_estimators=20;, score=0.929 total time=   0.1s
# [CV 5/5; 1/48] START max_depth=4, max_features=0.2, n_estimators=20.............
# [CV 5/5; 1/48] END max_depth=4, max_features=0.2, n_estimators=20;, score=0.928 total time=   0.1s
# [CV 1/5; 2/48] START max_depth=4, max_features=0.2, n_estimators=40.............
# [CV 1/5; 2/48] END max_depth=4, max_features=0.2, n_estimators=40;, score=0.936 total time=   0.2s
# [CV 2/5; 2/48] START max_depth=4, max_features=0.2, n_estimators=40.............
# [CV 2/5; 2/48] END max_depth=4, max_features=0.2, n_estimators=40;, score=0.933 total time=   0.2s
# [CV 3/5; 2/48] START max_depth=4, max_features=0.2, n_estimators=40.............
# [CV 3/5; 2/48] END max_depth=4, max_features=0.2, n_estimators=40;, score=0.947 total time=   0.3s
# [CV 4/5; 2/48] START max_depth=4, max_features=0.2, n_estimators=40.............
# [CV 4/5; 2/48] END max_depth=4, max_features=0.2, n_estimators=40;, score=0.936 total time=   0.3s
# [CV 5/5; 2/48] START max_depth=4, max_features=0.2, n_estimators=40.............
# [CV 5/5; 2/48] END max_depth=4, max_features=0.2, n_estimators=40;, score=0.943 total time=   0.3s
# [CV 1/5; 3/48] START max_depth=4, max_features=0.2, n_estimators=60.............
# [CV 1/5; 3/48] END max_depth=4, max_features=0.2, n_estimators=60;, score=0.940 total time=   0.4s
# [CV 2/5; 3/48] START max_depth=4, max_features=0.2, n_estimators=60.............
# [CV 2/5; 3/48] END max_depth=4, max_features=0.2, n_estimators=60;, score=0.942 total time=   0.4s
# [CV 3/5; 3/48] START max_depth=4, max_features=0.2, n_estimators=60.............
# [CV 3/5; 3/48] END max_depth=4, max_features=0.2, n_estimators=60;, score=0.957 total time=   0.4s
# [CV 4/5; 3/48] START max_depth=4, max_features=0.2, n_estimators=60.............
# [CV 4/5; 3/48] END max_depth=4, max_features=0.2, n_estimators=60;, score=0.938 total time=   0.4s
# [CV 5/5; 3/48] START max_depth=4, max_features=0.2, n_estimators=60.............
# [CV 5/5; 3/48] END max_depth=4, max_features=0.2, n_estimators=60;, score=0.948 total time=   0.4s
# [CV 1/5; 4/48] START max_depth=4, max_features=0.2, n_estimators=100............
# [CV 1/5; 4/48] END max_depth=4, max_features=0.2, n_estimators=100;, score=0.946 total time=   0.6s
# [CV 2/5; 4/48] START max_depth=4, max_features=0.2, n_estimators=100............
# [CV 2/5; 4/48] END max_depth=4, max_features=0.2, n_estimators=100;, score=0.948 total time=   0.5s
# [CV 3/5; 4/48] START max_depth=4, max_features=0.2, n_estimators=100............
# [CV 3/5; 4/48] END max_depth=4, max_features=0.2, n_estimators=100;, score=0.962 total time=   0.5s
# [CV 4/5; 4/48] START max_depth=4, max_features=0.2, n_estimators=100............
# [CV 4/5; 4/48] END max_depth=4, max_features=0.2, n_estimators=100;, score=0.942 total time=   0.5s
# [CV 5/5; 4/48] START max_depth=4, max_features=0.2, n_estimators=100............
# [CV 5/5; 4/48] END max_depth=4, max_features=0.2, n_estimators=100;, score=0.954 total time=   0.5s
# [CV 1/5; 5/48] START max_depth=4, max_features=0.5, n_estimators=20.............
# [CV 1/5; 5/48] END max_depth=4, max_features=0.5, n_estimators=20;, score=0.931 total time=   0.2s
# [CV 2/5; 5/48] START max_depth=4, max_features=0.5, n_estimators=20.............
# [CV 2/5; 5/48] END max_depth=4, max_features=0.5, n_estimators=20;, score=0.920 total time=   0.2s
# [CV 3/5; 5/48] START max_depth=4, max_features=0.5, n_estimators=20.............
# [CV 3/5; 5/48] END max_depth=4, max_features=0.5, n_estimators=20;, score=0.936 total time=   0.2s
# [CV 4/5; 5/48] START max_depth=4, max_features=0.5, n_estimators=20.............
# [CV 4/5; 5/48] END max_depth=4, max_features=0.5, n_estimators=20;, score=0.923 total time=   0.2s
# [CV 5/5; 5/48] START max_depth=4, max_features=0.5, n_estimators=20.............
# [CV 5/5; 5/48] END max_depth=4, max_features=0.5, n_estimators=20;, score=0.925 total time=   0.2s
# [CV 1/5; 6/48] START max_depth=4, max_features=0.5, n_estimators=40.............
# [CV 1/5; 6/48] END max_depth=4, max_features=0.5, n_estimators=40;, score=0.948 total time=   0.4s
# [CV 2/5; 6/48] START max_depth=4, max_features=0.5, n_estimators=40.............
# [CV 2/5; 6/48] END max_depth=4, max_features=0.5, n_estimators=40;, score=0.931 total time=   0.4s
# [CV 3/5; 6/48] START max_depth=4, max_features=0.5, n_estimators=40.............
# [CV 3/5; 6/48] END max_depth=4, max_features=0.5, n_estimators=40;, score=0.943 total time=   0.4s
# [CV 4/5; 6/48] START max_depth=4, max_features=0.5, n_estimators=40.............
# [CV 4/5; 6/48] END max_depth=4, max_features=0.5, n_estimators=40;, score=0.933 total time=   0.4s
# [CV 5/5; 6/48] START max_depth=4, max_features=0.5, n_estimators=40.............
# [CV 5/5; 6/48] END max_depth=4, max_features=0.5, n_estimators=40;, score=0.942 total time=   0.4s
# [CV 1/5; 7/48] START max_depth=4, max_features=0.5, n_estimators=60.............
# [CV 1/5; 7/48] END max_depth=4, max_features=0.5, n_estimators=60;, score=0.947 total time=   0.6s
# [CV 2/5; 7/48] START max_depth=4, max_features=0.5, n_estimators=60.............
# [CV 2/5; 7/48] END max_depth=4, max_features=0.5, n_estimators=60;, score=0.938 total time=   0.6s
# [CV 3/5; 7/48] START max_depth=4, max_features=0.5, n_estimators=60.............
# [CV 3/5; 7/48] END max_depth=4, max_features=0.5, n_estimators=60;, score=0.954 total time=   0.6s
# [CV 4/5; 7/48] START max_depth=4, max_features=0.5, n_estimators=60.............
# [CV 4/5; 7/48] END max_depth=4, max_features=0.5, n_estimators=60;, score=0.936 total time=   0.6s
# [CV 5/5; 7/48] START max_depth=4, max_features=0.5, n_estimators=60.............
# [CV 5/5; 7/48] END max_depth=4, max_features=0.5, n_estimators=60;, score=0.954 total time=   0.6s
# [CV 1/5; 8/48] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 1/5; 8/48] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.946 total time=   0.9s
# [CV 2/5; 8/48] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 2/5; 8/48] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.942 total time=   0.9s
# [CV 3/5; 8/48] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 3/5; 8/48] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.950 total time=   1.3s
# [CV 4/5; 8/48] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 4/5; 8/48] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.939 total time=   1.3s
# [CV 5/5; 8/48] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 5/5; 8/48] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.955 total time=   1.2s
# [CV 1/5; 9/48] START max_depth=4, max_features=0.8, n_estimators=20.............
# [CV 1/5; 9/48] END max_depth=4, max_features=0.8, n_estimators=20;, score=0.928 total time=   0.3s
# [CV 2/5; 9/48] START max_depth=4, max_features=0.8, n_estimators=20.............
# [CV 2/5; 9/48] END max_depth=4, max_features=0.8, n_estimators=20;, score=0.916 total time=   0.3s
# [CV 3/5; 9/48] START max_depth=4, max_features=0.8, n_estimators=20.............
# [CV 3/5; 9/48] END max_depth=4, max_features=0.8, n_estimators=20;, score=0.928 total time=   0.3s
# [CV 4/5; 9/48] START max_depth=4, max_features=0.8, n_estimators=20.............
# [CV 4/5; 9/48] END max_depth=4, max_features=0.8, n_estimators=20;, score=0.928 total time=   0.3s
# [CV 5/5; 9/48] START max_depth=4, max_features=0.8, n_estimators=20.............
# [CV 5/5; 9/48] END max_depth=4, max_features=0.8, n_estimators=20;, score=0.933 total time=   0.3s
# [CV 1/5; 10/48] START max_depth=4, max_features=0.8, n_estimators=40............
# [CV 1/5; 10/48] END max_depth=4, max_features=0.8, n_estimators=40;, score=0.946 total time=   0.6s
# [CV 2/5; 10/48] START max_depth=4, max_features=0.8, n_estimators=40............
# [CV 2/5; 10/48] END max_depth=4, max_features=0.8, n_estimators=40;, score=0.931 total time=   0.6s
# [CV 3/5; 10/48] START max_depth=4, max_features=0.8, n_estimators=40............
# [CV 3/5; 10/48] END max_depth=4, max_features=0.8, n_estimators=40;, score=0.946 total time=   0.6s
# [CV 4/5; 10/48] START max_depth=4, max_features=0.8, n_estimators=40............
# [CV 4/5; 10/48] END max_depth=4, max_features=0.8, n_estimators=40;, score=0.935 total time=   0.6s
# [CV 5/5; 10/48] START max_depth=4, max_features=0.8, n_estimators=40............
# [CV 5/5; 10/48] END max_depth=4, max_features=0.8, n_estimators=40;, score=0.940 total time=   0.6s
# [CV 1/5; 11/48] START max_depth=4, max_features=0.8, n_estimators=60............
# [CV 1/5; 11/48] END max_depth=4, max_features=0.8, n_estimators=60;, score=0.946 total time=   0.8s
# [CV 2/5; 11/48] START max_depth=4, max_features=0.8, n_estimators=60............
# [CV 2/5; 11/48] END max_depth=4, max_features=0.8, n_estimators=60;, score=0.939 total time=   0.8s
# [CV 3/5; 11/48] START max_depth=4, max_features=0.8, n_estimators=60............
# [CV 3/5; 11/48] END max_depth=4, max_features=0.8, n_estimators=60;, score=0.952 total time=   0.8s
# [CV 4/5; 11/48] START max_depth=4, max_features=0.8, n_estimators=60............
# [CV 4/5; 11/48] END max_depth=4, max_features=0.8, n_estimators=60;, score=0.939 total time=   0.8s
# [CV 5/5; 11/48] START max_depth=4, max_features=0.8, n_estimators=60............
# [CV 5/5; 11/48] END max_depth=4, max_features=0.8, n_estimators=60;, score=0.950 total time=   0.8s
# [CV 1/5; 12/48] START max_depth=4, max_features=0.8, n_estimators=100...........
# [CV 1/5; 12/48] END max_depth=4, max_features=0.8, n_estimators=100;, score=0.947 total time=   1.5s
# [CV 2/5; 12/48] START max_depth=4, max_features=0.8, n_estimators=100...........
# [CV 2/5; 12/48] END max_depth=4, max_features=0.8, n_estimators=100;, score=0.944 total time=   2.0s
# [CV 3/5; 12/48] START max_depth=4, max_features=0.8, n_estimators=100...........
# [CV 3/5; 12/48] END max_depth=4, max_features=0.8, n_estimators=100;, score=0.955 total time=   1.8s
# [CV 4/5; 12/48] START max_depth=4, max_features=0.8, n_estimators=100...........
# [CV 4/5; 12/48] END max_depth=4, max_features=0.8, n_estimators=100;, score=0.938 total time=   1.4s
# [CV 5/5; 12/48] START max_depth=4, max_features=0.8, n_estimators=100...........
# [CV 5/5; 12/48] END max_depth=4, max_features=0.8, n_estimators=100;, score=0.955 total time=   1.4s
# [CV 1/5; 13/48] START max_depth=6, max_features=0.2, n_estimators=20............
# [CV 1/5; 13/48] END max_depth=6, max_features=0.2, n_estimators=20;, score=0.943 total time=   0.2s
# [CV 2/5; 13/48] START max_depth=6, max_features=0.2, n_estimators=20............
# [CV 2/5; 13/48] END max_depth=6, max_features=0.2, n_estimators=20;, score=0.927 total time=   0.2s
# [CV 3/5; 13/48] START max_depth=6, max_features=0.2, n_estimators=20............
# [CV 3/5; 13/48] END max_depth=6, max_features=0.2, n_estimators=20;, score=0.944 total time=   0.1s
# [CV 4/5; 13/48] START max_depth=6, max_features=0.2, n_estimators=20............
# [CV 4/5; 13/48] END max_depth=6, max_features=0.2, n_estimators=20;, score=0.936 total time=   0.2s
# [CV 5/5; 13/48] START max_depth=6, max_features=0.2, n_estimators=20............
# [CV 5/5; 13/48] END max_depth=6, max_features=0.2, n_estimators=20;, score=0.938 total time=   0.1s
# [CV 1/5; 14/48] START max_depth=6, max_features=0.2, n_estimators=40............
# [CV 1/5; 14/48] END max_depth=6, max_features=0.2, n_estimators=40;, score=0.950 total time=   0.3s
# [CV 2/5; 14/48] START max_depth=6, max_features=0.2, n_estimators=40............
# [CV 2/5; 14/48] END max_depth=6, max_features=0.2, n_estimators=40;, score=0.938 total time=   0.3s
# [CV 3/5; 14/48] START max_depth=6, max_features=0.2, n_estimators=40............
# [CV 3/5; 14/48] END max_depth=6, max_features=0.2, n_estimators=40;, score=0.954 total time=   0.3s
# [CV 4/5; 14/48] START max_depth=6, max_features=0.2, n_estimators=40............
# [CV 4/5; 14/48] END max_depth=6, max_features=0.2, n_estimators=40;, score=0.939 total time=   0.3s
# [CV 5/5; 14/48] START max_depth=6, max_features=0.2, n_estimators=40............
# [CV 5/5; 14/48] END max_depth=6, max_features=0.2, n_estimators=40;, score=0.948 total time=   0.3s
# [CV 1/5; 15/48] START max_depth=6, max_features=0.2, n_estimators=60............
# [CV 1/5; 15/48] END max_depth=6, max_features=0.2, n_estimators=60;, score=0.951 total time=   0.5s
# [CV 2/5; 15/48] START max_depth=6, max_features=0.2, n_estimators=60............
# [CV 2/5; 15/48] END max_depth=6, max_features=0.2, n_estimators=60;, score=0.946 total time=   0.4s
# [CV 3/5; 15/48] START max_depth=6, max_features=0.2, n_estimators=60............
# [CV 3/5; 15/48] END max_depth=6, max_features=0.2, n_estimators=60;, score=0.962 total time=   0.4s
# [CV 4/5; 15/48] START max_depth=6, max_features=0.2, n_estimators=60............
# [CV 4/5; 15/48] END max_depth=6, max_features=0.2, n_estimators=60;, score=0.944 total time=   0.4s
# [CV 5/5; 15/48] START max_depth=6, max_features=0.2, n_estimators=60............
# [CV 5/5; 15/48] END max_depth=6, max_features=0.2, n_estimators=60;, score=0.955 total time=   0.4s
# [CV 1/5; 16/48] START max_depth=6, max_features=0.2, n_estimators=100...........
# [CV 1/5; 16/48] END max_depth=6, max_features=0.2, n_estimators=100;, score=0.957 total time=   0.7s
# [CV 2/5; 16/48] START max_depth=6, max_features=0.2, n_estimators=100...........
# [CV 2/5; 16/48] END max_depth=6, max_features=0.2, n_estimators=100;, score=0.947 total time=   0.7s
# [CV 3/5; 16/48] START max_depth=6, max_features=0.2, n_estimators=100...........
# [CV 3/5; 16/48] END max_depth=6, max_features=0.2, n_estimators=100;, score=0.963 total time=   0.7s
# [CV 4/5; 16/48] START max_depth=6, max_features=0.2, n_estimators=100...........
# [CV 4/5; 16/48] END max_depth=6, max_features=0.2, n_estimators=100;, score=0.940 total time=   1.0s
# [CV 5/5; 16/48] START max_depth=6, max_features=0.2, n_estimators=100...........
# [CV 5/5; 16/48] END max_depth=6, max_features=0.2, n_estimators=100;, score=0.958 total time=   1.0s
# [CV 1/5; 17/48] START max_depth=6, max_features=0.5, n_estimators=20............
# [CV 1/5; 17/48] END max_depth=6, max_features=0.5, n_estimators=20;, score=0.938 total time=   0.4s
# [CV 2/5; 17/48] START max_depth=6, max_features=0.5, n_estimators=20............
# [CV 2/5; 17/48] END max_depth=6, max_features=0.5, n_estimators=20;, score=0.925 total time=   0.4s
# [CV 3/5; 17/48] START max_depth=6, max_features=0.5, n_estimators=20............
# [CV 3/5; 17/48] END max_depth=6, max_features=0.5, n_estimators=20;, score=0.936 total time=   0.4s
# [CV 4/5; 17/48] START max_depth=6, max_features=0.5, n_estimators=20............
# [CV 4/5; 17/48] END max_depth=6, max_features=0.5, n_estimators=20;, score=0.925 total time=   0.3s
# [CV 5/5; 17/48] START max_depth=6, max_features=0.5, n_estimators=20............
# [CV 5/5; 17/48] END max_depth=6, max_features=0.5, n_estimators=20;, score=0.935 total time=   0.3s
# [CV 1/5; 18/48] START max_depth=6, max_features=0.5, n_estimators=40............
# [CV 1/5; 18/48] END max_depth=6, max_features=0.5, n_estimators=40;, score=0.943 total time=   0.6s
# [CV 2/5; 18/48] START max_depth=6, max_features=0.5, n_estimators=40............
# [CV 2/5; 18/48] END max_depth=6, max_features=0.5, n_estimators=40;, score=0.938 total time=   0.6s
# [CV 3/5; 18/48] START max_depth=6, max_features=0.5, n_estimators=40............
# [CV 3/5; 18/48] END max_depth=6, max_features=0.5, n_estimators=40;, score=0.954 total time=   0.6s
# [CV 4/5; 18/48] START max_depth=6, max_features=0.5, n_estimators=40............
# [CV 4/5; 18/48] END max_depth=6, max_features=0.5, n_estimators=40;, score=0.938 total time=   0.6s
# [CV 5/5; 18/48] START max_depth=6, max_features=0.5, n_estimators=40............
# [CV 5/5; 18/48] END max_depth=6, max_features=0.5, n_estimators=40;, score=0.946 total time=   0.6s
# [CV 1/5; 19/48] START max_depth=6, max_features=0.5, n_estimators=60............
# [CV 1/5; 19/48] END max_depth=6, max_features=0.5, n_estimators=60;, score=0.951 total time=   0.8s
# [CV 2/5; 19/48] START max_depth=6, max_features=0.5, n_estimators=60............
# [CV 2/5; 19/48] END max_depth=6, max_features=0.5, n_estimators=60;, score=0.939 total time=   0.8s
# [CV 3/5; 19/48] START max_depth=6, max_features=0.5, n_estimators=60............
# [CV 3/5; 19/48] END max_depth=6, max_features=0.5, n_estimators=60;, score=0.955 total time=   0.8s
# [CV 4/5; 19/48] START max_depth=6, max_features=0.5, n_estimators=60............
# [CV 4/5; 19/48] END max_depth=6, max_features=0.5, n_estimators=60;, score=0.942 total time=   0.8s
# [CV 5/5; 19/48] START max_depth=6, max_features=0.5, n_estimators=60............
# [CV 5/5; 19/48] END max_depth=6, max_features=0.5, n_estimators=60;, score=0.957 total time=   0.8s
# [CV 1/5; 20/48] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 1/5; 20/48] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.951 total time=   1.4s
# [CV 2/5; 20/48] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 2/5; 20/48] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.954 total time=   1.6s
# [CV 3/5; 20/48] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 3/5; 20/48] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.959 total time=   2.0s
# [CV 4/5; 20/48] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 4/5; 20/48] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.942 total time=   2.0s
# [CV 5/5; 20/48] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 5/5; 20/48] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.961 total time=   1.4s
# [CV 1/5; 21/48] START max_depth=6, max_features=0.8, n_estimators=20............
# [CV 1/5; 21/48] END max_depth=6, max_features=0.8, n_estimators=20;, score=0.936 total time=   0.4s
# [CV 2/5; 21/48] START max_depth=6, max_features=0.8, n_estimators=20............
# [CV 2/5; 21/48] END max_depth=6, max_features=0.8, n_estimators=20;, score=0.917 total time=   0.4s
# [CV 3/5; 21/48] START max_depth=6, max_features=0.8, n_estimators=20............
# [CV 3/5; 21/48] END max_depth=6, max_features=0.8, n_estimators=20;, score=0.939 total time=   0.4s
# [CV 4/5; 21/48] START max_depth=6, max_features=0.8, n_estimators=20............
# [CV 4/5; 21/48] END max_depth=6, max_features=0.8, n_estimators=20;, score=0.938 total time=   0.4s
# [CV 5/5; 21/48] START max_depth=6, max_features=0.8, n_estimators=20............
# [CV 5/5; 21/48] END max_depth=6, max_features=0.8, n_estimators=20;, score=0.935 total time=   0.4s
# [CV 1/5; 22/48] START max_depth=6, max_features=0.8, n_estimators=40............
# [CV 1/5; 22/48] END max_depth=6, max_features=0.8, n_estimators=40;, score=0.950 total time=   0.8s
# [CV 2/5; 22/48] START max_depth=6, max_features=0.8, n_estimators=40............
# [CV 2/5; 22/48] END max_depth=6, max_features=0.8, n_estimators=40;, score=0.935 total time=   0.8s
# [CV 3/5; 22/48] START max_depth=6, max_features=0.8, n_estimators=40............
# [CV 3/5; 22/48] END max_depth=6, max_features=0.8, n_estimators=40;, score=0.951 total time=   0.8s
# [CV 4/5; 22/48] START max_depth=6, max_features=0.8, n_estimators=40............
# [CV 4/5; 22/48] END max_depth=6, max_features=0.8, n_estimators=40;, score=0.936 total time=   0.8s
# [CV 5/5; 22/48] START max_depth=6, max_features=0.8, n_estimators=40............
# [CV 5/5; 22/48] END max_depth=6, max_features=0.8, n_estimators=40;, score=0.946 total time=   0.8s
# [CV 1/5; 23/48] START max_depth=6, max_features=0.8, n_estimators=60............
# [CV 1/5; 23/48] END max_depth=6, max_features=0.8, n_estimators=60;, score=0.952 total time=   1.3s
# [CV 2/5; 23/48] START max_depth=6, max_features=0.8, n_estimators=60............
# [CV 2/5; 23/48] END max_depth=6, max_features=0.8, n_estimators=60;, score=0.948 total time=   1.8s
# [CV 3/5; 23/48] START max_depth=6, max_features=0.8, n_estimators=60............
# [CV 3/5; 23/48] END max_depth=6, max_features=0.8, n_estimators=60;, score=0.952 total time=   1.7s
# [CV 4/5; 23/48] START max_depth=6, max_features=0.8, n_estimators=60............
# [CV 4/5; 23/48] END max_depth=6, max_features=0.8, n_estimators=60;, score=0.947 total time=   1.2s
# [CV 5/5; 23/48] START max_depth=6, max_features=0.8, n_estimators=60............
# [CV 5/5; 23/48] END max_depth=6, max_features=0.8, n_estimators=60;, score=0.950 total time=   1.2s
# [CV 1/5; 24/48] START max_depth=6, max_features=0.8, n_estimators=100...........
# [CV 1/5; 24/48] END max_depth=6, max_features=0.8, n_estimators=100;, score=0.948 total time=   2.0s
# [CV 2/5; 24/48] START max_depth=6, max_features=0.8, n_estimators=100...........
# [CV 2/5; 24/48] END max_depth=6, max_features=0.8, n_estimators=100;, score=0.950 total time=   2.6s
# [CV 3/5; 24/48] START max_depth=6, max_features=0.8, n_estimators=100...........
# [CV 3/5; 24/48] END max_depth=6, max_features=0.8, n_estimators=100;, score=0.961 total time=   2.3s
# [CV 4/5; 24/48] START max_depth=6, max_features=0.8, n_estimators=100...........
# [CV 4/5; 24/48] END max_depth=6, max_features=0.8, n_estimators=100;, score=0.946 total time=   2.8s
# [CV 5/5; 24/48] START max_depth=6, max_features=0.8, n_estimators=100...........
# [CV 5/5; 24/48] END max_depth=6, max_features=0.8, n_estimators=100;, score=0.957 total time=   2.3s
# [CV 1/5; 25/48] START max_depth=8, max_features=0.2, n_estimators=20............
# [CV 1/5; 25/48] END max_depth=8, max_features=0.2, n_estimators=20;, score=0.944 total time=   0.2s
# [CV 2/5; 25/48] START max_depth=8, max_features=0.2, n_estimators=20............
# [CV 2/5; 25/48] END max_depth=8, max_features=0.2, n_estimators=20;, score=0.935 total time=   0.2s
# [CV 3/5; 25/48] START max_depth=8, max_features=0.2, n_estimators=20............
# [CV 3/5; 25/48] END max_depth=8, max_features=0.2, n_estimators=20;, score=0.951 total time=   0.2s
# [CV 4/5; 25/48] START max_depth=8, max_features=0.2, n_estimators=20............
# [CV 4/5; 25/48] END max_depth=8, max_features=0.2, n_estimators=20;, score=0.938 total time=   0.2s
# [CV 5/5; 25/48] START max_depth=8, max_features=0.2, n_estimators=20............
# [CV 5/5; 25/48] END max_depth=8, max_features=0.2, n_estimators=20;, score=0.940 total time=   0.2s
# [CV 1/5; 26/48] START max_depth=8, max_features=0.2, n_estimators=40............
# [CV 1/5; 26/48] END max_depth=8, max_features=0.2, n_estimators=40;, score=0.948 total time=   0.4s
# [CV 2/5; 26/48] START max_depth=8, max_features=0.2, n_estimators=40............
# [CV 2/5; 26/48] END max_depth=8, max_features=0.2, n_estimators=40;, score=0.948 total time=   0.4s
# [CV 3/5; 26/48] START max_depth=8, max_features=0.2, n_estimators=40............
# [CV 3/5; 26/48] END max_depth=8, max_features=0.2, n_estimators=40;, score=0.962 total time=   0.4s
# [CV 4/5; 26/48] START max_depth=8, max_features=0.2, n_estimators=40............
# [CV 4/5; 26/48] END max_depth=8, max_features=0.2, n_estimators=40;, score=0.943 total time=   0.4s
# [CV 5/5; 26/48] START max_depth=8, max_features=0.2, n_estimators=40............
# [CV 5/5; 26/48] END max_depth=8, max_features=0.2, n_estimators=40;, score=0.947 total time=   0.4s
# [CV 1/5; 27/48] START max_depth=8, max_features=0.2, n_estimators=60............
# [CV 1/5; 27/48] END max_depth=8, max_features=0.2, n_estimators=60;, score=0.954 total time=   0.6s
# [CV 2/5; 27/48] START max_depth=8, max_features=0.2, n_estimators=60............
# [CV 2/5; 27/48] END max_depth=8, max_features=0.2, n_estimators=60;, score=0.954 total time=   0.6s
# [CV 3/5; 27/48] START max_depth=8, max_features=0.2, n_estimators=60............
# [CV 3/5; 27/48] END max_depth=8, max_features=0.2, n_estimators=60;, score=0.961 total time=   0.6s
# [CV 4/5; 27/48] START max_depth=8, max_features=0.2, n_estimators=60............
# [CV 4/5; 27/48] END max_depth=8, max_features=0.2, n_estimators=60;, score=0.948 total time=   0.6s
# [CV 5/5; 27/48] START max_depth=8, max_features=0.2, n_estimators=60............
# [CV 5/5; 27/48] END max_depth=8, max_features=0.2, n_estimators=60;, score=0.951 total time=   0.6s
# [CV 1/5; 28/48] START max_depth=8, max_features=0.2, n_estimators=100...........
# [CV 1/5; 28/48] END max_depth=8, max_features=0.2, n_estimators=100;, score=0.947 total time=   1.0s
# [CV 2/5; 28/48] START max_depth=8, max_features=0.2, n_estimators=100...........
# [CV 2/5; 28/48] END max_depth=8, max_features=0.2, n_estimators=100;, score=0.959 total time=   1.0s
# [CV 3/5; 28/48] START max_depth=8, max_features=0.2, n_estimators=100...........
# [CV 3/5; 28/48] END max_depth=8, max_features=0.2, n_estimators=100;, score=0.961 total time=   1.4s
# [CV 4/5; 28/48] START max_depth=8, max_features=0.2, n_estimators=100...........
# [CV 4/5; 28/48] END max_depth=8, max_features=0.2, n_estimators=100;, score=0.948 total time=   1.5s
# [CV 5/5; 28/48] START max_depth=8, max_features=0.2, n_estimators=100...........
# [CV 5/5; 28/48] END max_depth=8, max_features=0.2, n_estimators=100;, score=0.961 total time=   1.1s
# [CV 1/5; 29/48] START max_depth=8, max_features=0.5, n_estimators=20............
# [CV 1/5; 29/48] END max_depth=8, max_features=0.5, n_estimators=20;, score=0.943 total time=   0.4s
# [CV 2/5; 29/48] START max_depth=8, max_features=0.5, n_estimators=20............
# [CV 2/5; 29/48] END max_depth=8, max_features=0.5, n_estimators=20;, score=0.932 total time=   0.4s
# [CV 3/5; 29/48] START max_depth=8, max_features=0.5, n_estimators=20............
# [CV 3/5; 29/48] END max_depth=8, max_features=0.5, n_estimators=20;, score=0.946 total time=   0.4s
# [CV 4/5; 29/48] START max_depth=8, max_features=0.5, n_estimators=20............
# [CV 4/5; 29/48] END max_depth=8, max_features=0.5, n_estimators=20;, score=0.939 total time=   0.4s
# [CV 5/5; 29/48] START max_depth=8, max_features=0.5, n_estimators=20............
# [CV 5/5; 29/48] END max_depth=8, max_features=0.5, n_estimators=20;, score=0.943 total time=   0.4s
# [CV 1/5; 30/48] START max_depth=8, max_features=0.5, n_estimators=40............
# [CV 1/5; 30/48] END max_depth=8, max_features=0.5, n_estimators=40;, score=0.947 total time=   0.8s
# [CV 2/5; 30/48] START max_depth=8, max_features=0.5, n_estimators=40............
# [CV 2/5; 30/48] END max_depth=8, max_features=0.5, n_estimators=40;, score=0.939 total time=   0.8s
# [CV 3/5; 30/48] START max_depth=8, max_features=0.5, n_estimators=40............
# [CV 3/5; 30/48] END max_depth=8, max_features=0.5, n_estimators=40;, score=0.954 total time=   0.8s
# [CV 4/5; 30/48] START max_depth=8, max_features=0.5, n_estimators=40............
# [CV 4/5; 30/48] END max_depth=8, max_features=0.5, n_estimators=40;, score=0.939 total time=   0.8s
# [CV 5/5; 30/48] START max_depth=8, max_features=0.5, n_estimators=40............
# [CV 5/5; 30/48] END max_depth=8, max_features=0.5, n_estimators=40;, score=0.951 total time=   0.8s
# [CV 1/5; 31/48] START max_depth=8, max_features=0.5, n_estimators=60............
# [CV 1/5; 31/48] END max_depth=8, max_features=0.5, n_estimators=60;, score=0.948 total time=   1.2s
# [CV 2/5; 31/48] START max_depth=8, max_features=0.5, n_estimators=60............
# [CV 2/5; 31/48] END max_depth=8, max_features=0.5, n_estimators=60;, score=0.947 total time=   1.2s
# [CV 3/5; 31/48] START max_depth=8, max_features=0.5, n_estimators=60............
# [CV 3/5; 31/48] END max_depth=8, max_features=0.5, n_estimators=60;, score=0.955 total time=   1.2s
# [CV 4/5; 31/48] START max_depth=8, max_features=0.5, n_estimators=60............
# [CV 4/5; 31/48] END max_depth=8, max_features=0.5, n_estimators=60;, score=0.943 total time=   1.7s
# [CV 5/5; 31/48] START max_depth=8, max_features=0.5, n_estimators=60............
# [CV 5/5; 31/48] END max_depth=8, max_features=0.5, n_estimators=60;, score=0.957 total time=   1.7s
# [CV 1/5; 32/48] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 1/5; 32/48] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.950 total time=   1.9s
# [CV 2/5; 32/48] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 2/5; 32/48] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.951 total time=   1.9s
# [CV 3/5; 32/48] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 3/5; 32/48] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.961 total time=   1.9s
# [CV 4/5; 32/48] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 4/5; 32/48] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.944 total time=   1.9s
# [CV 5/5; 32/48] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 5/5; 32/48] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.959 total time=   1.9s
# [CV 1/5; 33/48] START max_depth=8, max_features=0.8, n_estimators=20............
# [CV 1/5; 33/48] END max_depth=8, max_features=0.8, n_estimators=20;, score=0.947 total time=   0.6s
# [CV 2/5; 33/48] START max_depth=8, max_features=0.8, n_estimators=20............
# [CV 2/5; 33/48] END max_depth=8, max_features=0.8, n_estimators=20;, score=0.923 total time=   0.8s
# [CV 3/5; 33/48] START max_depth=8, max_features=0.8, n_estimators=20............
# [CV 3/5; 33/48] END max_depth=8, max_features=0.8, n_estimators=20;, score=0.947 total time=   0.9s
# [CV 4/5; 33/48] START max_depth=8, max_features=0.8, n_estimators=20............
# [CV 4/5; 33/48] END max_depth=8, max_features=0.8, n_estimators=20;, score=0.933 total time=   0.8s
# [CV 5/5; 33/48] START max_depth=8, max_features=0.8, n_estimators=20............
# [CV 5/5; 33/48] END max_depth=8, max_features=0.8, n_estimators=20;, score=0.940 total time=   0.8s
# [CV 1/5; 34/48] START max_depth=8, max_features=0.8, n_estimators=40............
# [CV 1/5; 34/48] END max_depth=8, max_features=0.8, n_estimators=40;, score=0.954 total time=   1.2s
# [CV 2/5; 34/48] START max_depth=8, max_features=0.8, n_estimators=40............
# [CV 2/5; 34/48] END max_depth=8, max_features=0.8, n_estimators=40;, score=0.938 total time=   1.1s
# [CV 3/5; 34/48] START max_depth=8, max_features=0.8, n_estimators=40............
# [CV 3/5; 34/48] END max_depth=8, max_features=0.8, n_estimators=40;, score=0.957 total time=   1.1s
# [CV 4/5; 34/48] START max_depth=8, max_features=0.8, n_estimators=40............
# [CV 4/5; 34/48] END max_depth=8, max_features=0.8, n_estimators=40;, score=0.940 total time=   1.1s
# [CV 5/5; 34/48] START max_depth=8, max_features=0.8, n_estimators=40............
# [CV 5/5; 34/48] END max_depth=8, max_features=0.8, n_estimators=40;, score=0.957 total time=   1.1s
# [CV 1/5; 35/48] START max_depth=8, max_features=0.8, n_estimators=60............
# [CV 1/5; 35/48] END max_depth=8, max_features=0.8, n_estimators=60;, score=0.952 total time=   1.7s
# [CV 2/5; 35/48] START max_depth=8, max_features=0.8, n_estimators=60............
# [CV 2/5; 35/48] END max_depth=8, max_features=0.8, n_estimators=60;, score=0.944 total time=   1.7s
# [CV 3/5; 35/48] START max_depth=8, max_features=0.8, n_estimators=60............
# [CV 3/5; 35/48] END max_depth=8, max_features=0.8, n_estimators=60;, score=0.957 total time=   2.0s
# [CV 4/5; 35/48] START max_depth=8, max_features=0.8, n_estimators=60............
# [CV 4/5; 35/48] END max_depth=8, max_features=0.8, n_estimators=60;, score=0.944 total time=   2.4s
# [CV 5/5; 35/48] START max_depth=8, max_features=0.8, n_estimators=60............
# [CV 5/5; 35/48] END max_depth=8, max_features=0.8, n_estimators=60;, score=0.954 total time=   1.7s
# [CV 1/5; 36/48] START max_depth=8, max_features=0.8, n_estimators=100...........
# [CV 1/5; 36/48] END max_depth=8, max_features=0.8, n_estimators=100;, score=0.950 total time=   2.8s
# [CV 2/5; 36/48] START max_depth=8, max_features=0.8, n_estimators=100...........
# [CV 2/5; 36/48] END max_depth=8, max_features=0.8, n_estimators=100;, score=0.951 total time=   2.8s
# [CV 3/5; 36/48] START max_depth=8, max_features=0.8, n_estimators=100...........
# [CV 3/5; 36/48] END max_depth=8, max_features=0.8, n_estimators=100;, score=0.962 total time=   2.8s
# [CV 4/5; 36/48] START max_depth=8, max_features=0.8, n_estimators=100...........
# [CV 4/5; 36/48] END max_depth=8, max_features=0.8, n_estimators=100;, score=0.946 total time=   3.7s
# [CV 5/5; 36/48] START max_depth=8, max_features=0.8, n_estimators=100...........
# [CV 5/5; 36/48] END max_depth=8, max_features=0.8, n_estimators=100;, score=0.954 total time=   2.8s
# [CV 1/5; 37/48] START max_depth=10, max_features=0.2, n_estimators=20...........
# [CV 1/5; 37/48] END max_depth=10, max_features=0.2, n_estimators=20;, score=0.938 total time=   0.3s
# [CV 2/5; 37/48] START max_depth=10, max_features=0.2, n_estimators=20...........
# [CV 2/5; 37/48] END max_depth=10, max_features=0.2, n_estimators=20;, score=0.950 total time=   0.3s
# [CV 3/5; 37/48] START max_depth=10, max_features=0.2, n_estimators=20...........
# [CV 3/5; 37/48] END max_depth=10, max_features=0.2, n_estimators=20;, score=0.947 total time=   0.3s
# [CV 4/5; 37/48] START max_depth=10, max_features=0.2, n_estimators=20...........
# [CV 4/5; 37/48] END max_depth=10, max_features=0.2, n_estimators=20;, score=0.935 total time=   0.3s
# [CV 5/5; 37/48] START max_depth=10, max_features=0.2, n_estimators=20...........
# [CV 5/5; 37/48] END max_depth=10, max_features=0.2, n_estimators=20;, score=0.947 total time=   0.3s
# [CV 1/5; 38/48] START max_depth=10, max_features=0.2, n_estimators=40...........
# [CV 1/5; 38/48] END max_depth=10, max_features=0.2, n_estimators=40;, score=0.950 total time=   0.6s
# [CV 2/5; 38/48] START max_depth=10, max_features=0.2, n_estimators=40...........
# [CV 2/5; 38/48] END max_depth=10, max_features=0.2, n_estimators=40;, score=0.950 total time=   0.6s
# [CV 3/5; 38/48] START max_depth=10, max_features=0.2, n_estimators=40...........
# [CV 3/5; 38/48] END max_depth=10, max_features=0.2, n_estimators=40;, score=0.958 total time=   0.6s
# [CV 4/5; 38/48] START max_depth=10, max_features=0.2, n_estimators=40...........
# [CV 4/5; 38/48] END max_depth=10, max_features=0.2, n_estimators=40;, score=0.940 total time=   0.6s
# [CV 5/5; 38/48] START max_depth=10, max_features=0.2, n_estimators=40...........
# [CV 5/5; 38/48] END max_depth=10, max_features=0.2, n_estimators=40;, score=0.955 total time=   0.6s
# [CV 1/5; 39/48] START max_depth=10, max_features=0.2, n_estimators=60...........
# [CV 1/5; 39/48] END max_depth=10, max_features=0.2, n_estimators=60;, score=0.955 total time=   0.9s
# [CV 2/5; 39/48] START max_depth=10, max_features=0.2, n_estimators=60...........
# [CV 2/5; 39/48] END max_depth=10, max_features=0.2, n_estimators=60;, score=0.950 total time=   0.9s
# [CV 3/5; 39/48] START max_depth=10, max_features=0.2, n_estimators=60...........
# [CV 3/5; 39/48] END max_depth=10, max_features=0.2, n_estimators=60;, score=0.969 total time=   1.2s
# [CV 4/5; 39/48] START max_depth=10, max_features=0.2, n_estimators=60...........
# [CV 4/5; 39/48] END max_depth=10, max_features=0.2, n_estimators=60;, score=0.942 total time=   1.4s
# [CV 5/5; 39/48] START max_depth=10, max_features=0.2, n_estimators=60...........
# [CV 5/5; 39/48] END max_depth=10, max_features=0.2, n_estimators=60;, score=0.957 total time=   1.9s
# [CV 1/5; 40/48] START max_depth=10, max_features=0.2, n_estimators=100..........
# [CV 1/5; 40/48] END max_depth=10, max_features=0.2, n_estimators=100;, score=0.958 total time=   1.4s
# [CV 2/5; 40/48] START max_depth=10, max_features=0.2, n_estimators=100..........
# [CV 2/5; 40/48] END max_depth=10, max_features=0.2, n_estimators=100;, score=0.958 total time=   1.4s
# [CV 3/5; 40/48] START max_depth=10, max_features=0.2, n_estimators=100..........
# [CV 3/5; 40/48] END max_depth=10, max_features=0.2, n_estimators=100;, score=0.969 total time=   1.4s
# [CV 4/5; 40/48] START max_depth=10, max_features=0.2, n_estimators=100..........
# [CV 4/5; 40/48] END max_depth=10, max_features=0.2, n_estimators=100;, score=0.948 total time=   1.4s
# [CV 5/5; 40/48] START max_depth=10, max_features=0.2, n_estimators=100..........
# [CV 5/5; 40/48] END max_depth=10, max_features=0.2, n_estimators=100;, score=0.957 total time=   1.4s
# [CV 1/5; 41/48] START max_depth=10, max_features=0.5, n_estimators=20...........
# [CV 1/5; 41/48] END max_depth=10, max_features=0.5, n_estimators=20;, score=0.940 total time=   0.5s
# [CV 2/5; 41/48] START max_depth=10, max_features=0.5, n_estimators=20...........
# [CV 2/5; 41/48] END max_depth=10, max_features=0.5, n_estimators=20;, score=0.938 total time=   0.5s
# [CV 3/5; 41/48] START max_depth=10, max_features=0.5, n_estimators=20...........
# [CV 3/5; 41/48] END max_depth=10, max_features=0.5, n_estimators=20;, score=0.946 total time=   0.5s
# [CV 4/5; 41/48] START max_depth=10, max_features=0.5, n_estimators=20...........
# [CV 4/5; 41/48] END max_depth=10, max_features=0.5, n_estimators=20;, score=0.932 total time=   0.5s
# [CV 5/5; 41/48] START max_depth=10, max_features=0.5, n_estimators=20...........
# [CV 5/5; 41/48] END max_depth=10, max_features=0.5, n_estimators=20;, score=0.948 total time=   0.7s
# [CV 1/5; 42/48] START max_depth=10, max_features=0.5, n_estimators=40...........
# [CV 1/5; 42/48] END max_depth=10, max_features=0.5, n_estimators=40;, score=0.946 total time=   1.5s
# [CV 2/5; 42/48] START max_depth=10, max_features=0.5, n_estimators=40...........
# [CV 2/5; 42/48] END max_depth=10, max_features=0.5, n_estimators=40;, score=0.950 total time=   1.5s
# [CV 3/5; 42/48] START max_depth=10, max_features=0.5, n_estimators=40...........
# [CV 3/5; 42/48] END max_depth=10, max_features=0.5, n_estimators=40;, score=0.955 total time=   1.0s
# [CV 4/5; 42/48] START max_depth=10, max_features=0.5, n_estimators=40...........
# [CV 4/5; 42/48] END max_depth=10, max_features=0.5, n_estimators=40;, score=0.936 total time=   1.0s
# [CV 5/5; 42/48] START max_depth=10, max_features=0.5, n_estimators=40...........
# [CV 5/5; 42/48] END max_depth=10, max_features=0.5, n_estimators=40;, score=0.957 total time=   1.0s
# [CV 1/5; 43/48] START max_depth=10, max_features=0.5, n_estimators=60...........
# [CV 1/5; 43/48] END max_depth=10, max_features=0.5, n_estimators=60;, score=0.950 total time=   1.5s
# [CV 2/5; 43/48] START max_depth=10, max_features=0.5, n_estimators=60...........
# [CV 2/5; 43/48] END max_depth=10, max_features=0.5, n_estimators=60;, score=0.948 total time=   1.5s
# [CV 3/5; 43/48] START max_depth=10, max_features=0.5, n_estimators=60...........
# [CV 3/5; 43/48] END max_depth=10, max_features=0.5, n_estimators=60;, score=0.965 total time=   1.5s
# [CV 4/5; 43/48] START max_depth=10, max_features=0.5, n_estimators=60...........
# [CV 4/5; 43/48] END max_depth=10, max_features=0.5, n_estimators=60;, score=0.942 total time=   1.5s
# [CV 5/5; 43/48] START max_depth=10, max_features=0.5, n_estimators=60...........
# [CV 5/5; 43/48] END max_depth=10, max_features=0.5, n_estimators=60;, score=0.955 total time=   2.0s
# [CV 1/5; 44/48] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 1/5; 44/48] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.950 total time=   3.2s
# [CV 2/5; 44/48] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 2/5; 44/48] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.950 total time=   2.5s
# [CV 3/5; 44/48] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 3/5; 44/48] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.962 total time=   2.5s
# [CV 4/5; 44/48] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 4/5; 44/48] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.946 total time=   2.5s
# [CV 5/5; 44/48] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 5/5; 44/48] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.951 total time=   2.9s
# [CV 1/5; 45/48] START max_depth=10, max_features=0.8, n_estimators=20...........
# [CV 1/5; 45/48] END max_depth=10, max_features=0.8, n_estimators=20;, score=0.942 total time=   1.1s
# [CV 2/5; 45/48] START max_depth=10, max_features=0.8, n_estimators=20...........
# [CV 2/5; 45/48] END max_depth=10, max_features=0.8, n_estimators=20;, score=0.933 total time=   1.0s
# [CV 3/5; 45/48] START max_depth=10, max_features=0.8, n_estimators=20...........
# [CV 3/5; 45/48] END max_depth=10, max_features=0.8, n_estimators=20;, score=0.947 total time=   0.7s
# [CV 4/5; 45/48] START max_depth=10, max_features=0.8, n_estimators=20...........
# [CV 4/5; 45/48] END max_depth=10, max_features=0.8, n_estimators=20;, score=0.932 total time=   0.7s
# [CV 5/5; 45/48] START max_depth=10, max_features=0.8, n_estimators=20...........
# [CV 5/5; 45/48] END max_depth=10, max_features=0.8, n_estimators=20;, score=0.947 total time=   0.7s
# [CV 1/5; 46/48] START max_depth=10, max_features=0.8, n_estimators=40...........
# [CV 1/5; 46/48] END max_depth=10, max_features=0.8, n_estimators=40;, score=0.939 total time=   1.5s
# [CV 2/5; 46/48] START max_depth=10, max_features=0.8, n_estimators=40...........
# [CV 2/5; 46/48] END max_depth=10, max_features=0.8, n_estimators=40;, score=0.943 total time=   1.5s
# [CV 3/5; 46/48] START max_depth=10, max_features=0.8, n_estimators=40...........
# [CV 3/5; 46/48] END max_depth=10, max_features=0.8, n_estimators=40;, score=0.951 total time=   1.4s
# [CV 4/5; 46/48] START max_depth=10, max_features=0.8, n_estimators=40...........
# [CV 4/5; 46/48] END max_depth=10, max_features=0.8, n_estimators=40;, score=0.938 total time=   1.4s
# [CV 5/5; 46/48] START max_depth=10, max_features=0.8, n_estimators=40...........
# [CV 5/5; 46/48] END max_depth=10, max_features=0.8, n_estimators=40;, score=0.950 total time=   1.5s
# [CV 1/5; 47/48] START max_depth=10, max_features=0.8, n_estimators=60...........
# [CV 1/5; 47/48] END max_depth=10, max_features=0.8, n_estimators=60;, score=0.951 total time=   3.0s
# [CV 2/5; 47/48] START max_depth=10, max_features=0.8, n_estimators=60...........
# [CV 2/5; 47/48] END max_depth=10, max_features=0.8, n_estimators=60;, score=0.950 total time=   2.4s
# [CV 3/5; 47/48] START max_depth=10, max_features=0.8, n_estimators=60...........
# [CV 3/5; 47/48] END max_depth=10, max_features=0.8, n_estimators=60;, score=0.959 total time=   2.2s
# [CV 4/5; 47/48] START max_depth=10, max_features=0.8, n_estimators=60...........
# [CV 4/5; 47/48] END max_depth=10, max_features=0.8, n_estimators=60;, score=0.943 total time=   2.1s
# [CV 5/5; 47/48] START max_depth=10, max_features=0.8, n_estimators=60...........
# [CV 5/5; 47/48] END max_depth=10, max_features=0.8, n_estimators=60;, score=0.954 total time=   2.2s
# [CV 1/5; 48/48] START max_depth=10, max_features=0.8, n_estimators=100..........
# [CV 1/5; 48/48] END max_depth=10, max_features=0.8, n_estimators=100;, score=0.952 total time=   4.3s
# [CV 2/5; 48/48] START max_depth=10, max_features=0.8, n_estimators=100..........
# [CV 2/5; 48/48] END max_depth=10, max_features=0.8, n_estimators=100;, score=0.952 total time=   4.0s
# [CV 3/5; 48/48] START max_depth=10, max_features=0.8, n_estimators=100..........
# [CV 3/5; 48/48] END max_depth=10, max_features=0.8, n_estimators=100;, score=0.962 total time=   3.5s
# [CV 4/5; 48/48] START max_depth=10, max_features=0.8, n_estimators=100..........
# [CV 4/5; 48/48] END max_depth=10, max_features=0.8, n_estimators=100;, score=0.947 total time=   3.6s
# [CV 5/5; 48/48] START max_depth=10, max_features=0.8, n_estimators=100..........
# [CV 5/5; 48/48] END max_depth=10, max_features=0.8, n_estimators=100;, score=0.959 total time=   8.1s
# Precisión: 95.2% con {'max_depth': 10, 'max_features': 0.2, 'n_estimators': 100}

# %% [markdown]
# ### Acelerar la búsqueda de parámetros: RandomizedSearch
#
# Un problema recurrente que tenemos en estos experimentos es el coste temporal de encontrar los mejores parámetros mediante GridSearch. Una alternativa que reduce dicho coste temporal es el [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# **Ejercicio** Implementa la misma búsqueda de valores que has realizado con GridSearch pero ahora con RandomizedSearch con n_iter=10 para limitar el número de pruebas a 10.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

#Crea el clasificador Adaboost
gb = GradientBoostingClassifier()

## Grid Search
G = {"n_estimators":[50,75,100,150],
     "max_depth":[2,4,6,8,10],
     "max_features":[0.25,0.5,1.0]}

RS = RandomizedSearchCV(gb, G, scoring='accuracy',n_iter=15, refit=True, cv=5, verbose=10)

acc = RS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {RS.best_params_}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START max_depth=2, max_features=1.0, n_estimators=150............
# [CV 1/5; 1/15] END max_depth=2, max_features=1.0, n_estimators=150;, score=0.948 total time=   2.8s
# [CV 2/5; 1/15] START max_depth=2, max_features=1.0, n_estimators=150............
# [CV 2/5; 1/15] END max_depth=2, max_features=1.0, n_estimators=150;, score=0.943 total time=   2.9s
# [CV 3/5; 1/15] START max_depth=2, max_features=1.0, n_estimators=150............
# [CV 3/5; 1/15] END max_depth=2, max_features=1.0, n_estimators=150;, score=0.955 total time=   1.4s
# [CV 4/5; 1/15] START max_depth=2, max_features=1.0, n_estimators=150............
# [CV 4/5; 1/15] END max_depth=2, max_features=1.0, n_estimators=150;, score=0.938 total time=   1.3s
# [CV 5/5; 1/15] START max_depth=2, max_features=1.0, n_estimators=150............
# [CV 5/5; 1/15] END max_depth=2, max_features=1.0, n_estimators=150;, score=0.952 total time=   1.3s
# [CV 1/5; 2/15] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 1/5; 2/15] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.955 total time=   3.4s
# [CV 2/5; 2/15] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 2/5; 2/15] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.948 total time=   3.8s
# [CV 3/5; 2/15] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 3/5; 2/15] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.967 total time=   4.0s
# [CV 4/5; 2/15] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 4/5; 2/15] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.951 total time=   3.4s
# [CV 5/5; 2/15] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 5/5; 2/15] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.954 total time=   3.4s
# [CV 1/5; 3/15] START max_depth=10, max_features=0.25, n_estimators=100..........
# [CV 1/5; 3/15] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.957 total time=   1.8s
# [CV 2/5; 3/15] START max_depth=10, max_features=0.25, n_estimators=100..........
# [CV 2/5; 3/15] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.958 total time=   2.4s
# [CV 3/5; 3/15] START max_depth=10, max_features=0.25, n_estimators=100..........
# [CV 3/5; 3/15] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.966 total time=   1.7s
# [CV 4/5; 3/15] START max_depth=10, max_features=0.25, n_estimators=100..........
# [CV 4/5; 3/15] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.948 total time=   1.6s
# [CV 5/5; 3/15] START max_depth=10, max_features=0.25, n_estimators=100..........
# [CV 5/5; 3/15] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.957 total time=   1.6s
# [CV 1/5; 4/15] START max_depth=4, max_features=0.25, n_estimators=50............
# [CV 1/5; 4/15] END max_depth=4, max_features=0.25, n_estimators=50;, score=0.940 total time=   0.3s
# [CV 2/5; 4/15] START max_depth=4, max_features=0.25, n_estimators=50............
# [CV 2/5; 4/15] END max_depth=4, max_features=0.25, n_estimators=50;, score=0.935 total time=   0.3s
# [CV 3/5; 4/15] START max_depth=4, max_features=0.25, n_estimators=50............
# [CV 3/5; 4/15] END max_depth=4, max_features=0.25, n_estimators=50;, score=0.946 total time=   0.3s
# [CV 4/5; 4/15] START max_depth=4, max_features=0.25, n_estimators=50............
# [CV 4/5; 4/15] END max_depth=4, max_features=0.25, n_estimators=50;, score=0.936 total time=   0.3s
# [CV 5/5; 4/15] START max_depth=4, max_features=0.25, n_estimators=50............
# [CV 5/5; 4/15] END max_depth=4, max_features=0.25, n_estimators=50;, score=0.951 total time=   0.3s
# [CV 1/5; 5/15] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 1/5; 5/15] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.952 total time=   1.9s
# [CV 2/5; 5/15] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 2/5; 5/15] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.954 total time=   1.9s
# [CV 3/5; 5/15] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 3/5; 5/15] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.963 total time=   2.7s
# [CV 4/5; 5/15] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 4/5; 5/15] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.940 total time=   2.1s
# [CV 5/5; 5/15] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 5/5; 5/15] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.962 total time=   1.9s
# [CV 1/5; 6/15] START max_depth=6, max_features=1.0, n_estimators=75.............
# [CV 1/5; 6/15] END max_depth=6, max_features=1.0, n_estimators=75;, score=0.955 total time=   1.9s
# [CV 2/5; 6/15] START max_depth=6, max_features=1.0, n_estimators=75.............
# [CV 2/5; 6/15] END max_depth=6, max_features=1.0, n_estimators=75;, score=0.946 total time=   1.9s
# [CV 3/5; 6/15] START max_depth=6, max_features=1.0, n_estimators=75.............
# [CV 3/5; 6/15] END max_depth=6, max_features=1.0, n_estimators=75;, score=0.957 total time=   1.9s
# [CV 4/5; 6/15] START max_depth=6, max_features=1.0, n_estimators=75.............
# [CV 4/5; 6/15] END max_depth=6, max_features=1.0, n_estimators=75;, score=0.944 total time=   2.7s
# [CV 5/5; 6/15] START max_depth=6, max_features=1.0, n_estimators=75.............
# [CV 5/5; 6/15] END max_depth=6, max_features=1.0, n_estimators=75;, score=0.954 total time=   2.3s
# [CV 1/5; 7/15] START max_depth=10, max_features=0.5, n_estimators=150...........
# [CV 1/5; 7/15] END max_depth=10, max_features=0.5, n_estimators=150;, score=0.954 total time=   3.7s
# [CV 2/5; 7/15] START max_depth=10, max_features=0.5, n_estimators=150...........
# [CV 2/5; 7/15] END max_depth=10, max_features=0.5, n_estimators=150;, score=0.959 total time=   3.7s
# [CV 3/5; 7/15] START max_depth=10, max_features=0.5, n_estimators=150...........
# [CV 3/5; 7/15] END max_depth=10, max_features=0.5, n_estimators=150;, score=0.959 total time=   4.6s
# [CV 4/5; 7/15] START max_depth=10, max_features=0.5, n_estimators=150...........
# [CV 4/5; 7/15] END max_depth=10, max_features=0.5, n_estimators=150;, score=0.946 total time=   3.7s
# [CV 5/5; 7/15] START max_depth=10, max_features=0.5, n_estimators=150...........
# [CV 5/5; 7/15] END max_depth=10, max_features=0.5, n_estimators=150;, score=0.954 total time=   3.6s
# [CV 1/5; 8/15] START max_depth=10, max_features=0.25, n_estimators=75...........
# [CV 1/5; 8/15] END max_depth=10, max_features=0.25, n_estimators=75;, score=0.952 total time=   1.2s
# [CV 2/5; 8/15] START max_depth=10, max_features=0.25, n_estimators=75...........
# [CV 2/5; 8/15] END max_depth=10, max_features=0.25, n_estimators=75;, score=0.955 total time=   1.2s
# [CV 3/5; 8/15] START max_depth=10, max_features=0.25, n_estimators=75...........
# [CV 3/5; 8/15] END max_depth=10, max_features=0.25, n_estimators=75;, score=0.966 total time=   1.6s
# [CV 4/5; 8/15] START max_depth=10, max_features=0.25, n_estimators=75...........
# [CV 4/5; 8/15] END max_depth=10, max_features=0.25, n_estimators=75;, score=0.943 total time=   1.9s
# [CV 5/5; 8/15] START max_depth=10, max_features=0.25, n_estimators=75...........
# [CV 5/5; 8/15] END max_depth=10, max_features=0.25, n_estimators=75;, score=0.961 total time=   1.4s
# [CV 1/5; 9/15] START max_depth=4, max_features=1.0, n_estimators=75.............
# [CV 1/5; 9/15] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.947 total time=   1.3s
# [CV 2/5; 9/15] START max_depth=4, max_features=1.0, n_estimators=75.............
# [CV 2/5; 9/15] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.940 total time=   1.3s
# [CV 3/5; 9/15] START max_depth=4, max_features=1.0, n_estimators=75.............
# [CV 3/5; 9/15] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.954 total time=   1.3s
# [CV 4/5; 9/15] START max_depth=4, max_features=1.0, n_estimators=75.............
# [CV 4/5; 9/15] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.938 total time=   1.3s
# [CV 5/5; 9/15] START max_depth=4, max_features=1.0, n_estimators=75.............
# [CV 5/5; 9/15] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.952 total time=   1.3s
# [CV 1/5; 10/15] START max_depth=6, max_features=0.5, n_estimators=50............
# [CV 1/5; 10/15] END max_depth=6, max_features=0.5, n_estimators=50;, score=0.948 total time=   0.7s
# [CV 2/5; 10/15] START max_depth=6, max_features=0.5, n_estimators=50............
# [CV 2/5; 10/15] END max_depth=6, max_features=0.5, n_estimators=50;, score=0.946 total time=   0.7s
# [CV 3/5; 10/15] START max_depth=6, max_features=0.5, n_estimators=50............
# [CV 3/5; 10/15] END max_depth=6, max_features=0.5, n_estimators=50;, score=0.957 total time=   0.7s
# [CV 4/5; 10/15] START max_depth=6, max_features=0.5, n_estimators=50............
# [CV 4/5; 10/15] END max_depth=6, max_features=0.5, n_estimators=50;, score=0.938 total time=   0.7s
# [CV 5/5; 10/15] START max_depth=6, max_features=0.5, n_estimators=50............
# [CV 5/5; 10/15] END max_depth=6, max_features=0.5, n_estimators=50;, score=0.957 total time=   1.0s
# [CV 1/5; 11/15] START max_depth=2, max_features=0.5, n_estimators=75............
# [CV 1/5; 11/15] END max_depth=2, max_features=0.5, n_estimators=75;, score=0.938 total time=   0.6s
# [CV 2/5; 11/15] START max_depth=2, max_features=0.5, n_estimators=75............
# [CV 2/5; 11/15] END max_depth=2, max_features=0.5, n_estimators=75;, score=0.924 total time=   0.6s
# [CV 3/5; 11/15] START max_depth=2, max_features=0.5, n_estimators=75............
# [CV 3/5; 11/15] END max_depth=2, max_features=0.5, n_estimators=75;, score=0.942 total time=   0.6s
# [CV 4/5; 11/15] START max_depth=2, max_features=0.5, n_estimators=75............
# [CV 4/5; 11/15] END max_depth=2, max_features=0.5, n_estimators=75;, score=0.931 total time=   0.5s
# [CV 5/5; 11/15] START max_depth=2, max_features=0.5, n_estimators=75............
# [CV 5/5; 11/15] END max_depth=2, max_features=0.5, n_estimators=75;, score=0.940 total time=   0.4s
# [CV 1/5; 12/15] START max_depth=6, max_features=1.0, n_estimators=50............
# [CV 1/5; 12/15] END max_depth=6, max_features=1.0, n_estimators=50;, score=0.946 total time=   1.3s
# [CV 2/5; 12/15] START max_depth=6, max_features=1.0, n_estimators=50............
# [CV 2/5; 12/15] END max_depth=6, max_features=1.0, n_estimators=50;, score=0.946 total time=   1.3s
# [CV 3/5; 12/15] START max_depth=6, max_features=1.0, n_estimators=50............
# [CV 3/5; 12/15] END max_depth=6, max_features=1.0, n_estimators=50;, score=0.957 total time=   1.3s
# [CV 4/5; 12/15] START max_depth=6, max_features=1.0, n_estimators=50............
# [CV 4/5; 12/15] END max_depth=6, max_features=1.0, n_estimators=50;, score=0.942 total time=   1.3s
# [CV 5/5; 12/15] START max_depth=6, max_features=1.0, n_estimators=50............
# [CV 5/5; 12/15] END max_depth=6, max_features=1.0, n_estimators=50;, score=0.948 total time=   1.3s
# [CV 1/5; 13/15] START max_depth=6, max_features=0.25, n_estimators=50...........
# [CV 1/5; 13/15] END max_depth=6, max_features=0.25, n_estimators=50;, score=0.947 total time=   0.4s
# [CV 2/5; 13/15] START max_depth=6, max_features=0.25, n_estimators=50...........
# [CV 2/5; 13/15] END max_depth=6, max_features=0.25, n_estimators=50;, score=0.947 total time=   0.4s
# [CV 3/5; 13/15] START max_depth=6, max_features=0.25, n_estimators=50...........
# [CV 3/5; 13/15] END max_depth=6, max_features=0.25, n_estimators=50;, score=0.954 total time=   0.4s
# [CV 4/5; 13/15] START max_depth=6, max_features=0.25, n_estimators=50...........
# [CV 4/5; 13/15] END max_depth=6, max_features=0.25, n_estimators=50;, score=0.943 total time=   0.8s
# [CV 5/5; 13/15] START max_depth=6, max_features=0.25, n_estimators=50...........
# [CV 5/5; 13/15] END max_depth=6, max_features=0.25, n_estimators=50;, score=0.952 total time=   0.4s
# [CV 1/5; 14/15] START max_depth=2, max_features=1.0, n_estimators=75............
# [CV 1/5; 14/15] END max_depth=2, max_features=1.0, n_estimators=75;, score=0.935 total time=   0.7s
# [CV 2/5; 14/15] START max_depth=2, max_features=1.0, n_estimators=75............
# [CV 2/5; 14/15] END max_depth=2, max_features=1.0, n_estimators=75;, score=0.924 total time=   1.0s
# [CV 3/5; 14/15] START max_depth=2, max_features=1.0, n_estimators=75............
# [CV 3/5; 14/15] END max_depth=2, max_features=1.0, n_estimators=75;, score=0.944 total time=   1.0s
# [CV 4/5; 14/15] START max_depth=2, max_features=1.0, n_estimators=75............
# [CV 4/5; 14/15] END max_depth=2, max_features=1.0, n_estimators=75;, score=0.935 total time=   1.0s
# [CV 5/5; 14/15] START max_depth=2, max_features=1.0, n_estimators=75............
# [CV 5/5; 14/15] END max_depth=2, max_features=1.0, n_estimators=75;, score=0.944 total time=   0.7s
# [CV 1/5; 15/15] START max_depth=6, max_features=0.5, n_estimators=150...........
# [CV 1/5; 15/15] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.950 total time=   2.1s
# [CV 2/5; 15/15] START max_depth=6, max_features=0.5, n_estimators=150...........
# [CV 2/5; 15/15] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.954 total time=   2.1s
# [CV 3/5; 15/15] START max_depth=6, max_features=0.5, n_estimators=150...........
# [CV 3/5; 15/15] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.958 total time=   2.0s
# [CV 4/5; 15/15] START max_depth=6, max_features=0.5, n_estimators=150...........
# [CV 4/5; 15/15] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.948 total time=   2.0s
# [CV 5/5; 15/15] START max_depth=6, max_features=0.5, n_estimators=150...........
# [CV 5/5; 15/15] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.957 total time=   2.4s
# Precisión: 95.5% con {'n_estimators': 100, 'max_features': 0.25, 'max_depth': 10}

# %% [markdown]
# ### Mejorar la búsqueda de parámetros: BayesianOptimization
#
# Optimización Bayesiana es una técnica avanzada de búsqueda de parámetros. Para poder emplearla hay que instalar la librería scikit-optimize. El uso de dicha técnica es similar a las ya empleadas con la diferencia que el rango de los parámetros hay que definirlos teniendo en cuenta además el tipo de los mismos: real, entero o categórico. Además los valores a probar no se listan explícitamente si no que se especifica un rango dentro del cual el algoritmo escogerá los valores.
#
# La ejecución puede resultar más lenta pero se pueden explorar más parámetros, de hecho se especifica un intervalo en lugar de valores concretos.

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.1-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-24.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-24.4.0 scikit-optimize-0.10.1

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
G={"max_depth": Integer(2,10),
   "n_estimators": Integer(50,200),
   "max_features": Real(0.1,1.0)}

BS = BayesSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=2, max_features=0.5, n_estimators=100.............
# [CV 1/5; 1/1] END max_depth=2, max_features=0.5, n_estimators=100;, score=0.943 total time=   1.6s
# [CV 2/5; 1/1] START max_depth=2, max_features=0.5, n_estimators=100.............
# [CV 2/5; 1/1] END max_depth=2, max_features=0.5, n_estimators=100;, score=0.932 total time=   1.9s
# [CV 3/5; 1/1] START max_depth=2, max_features=0.5, n_estimators=100.............
# [CV 3/5; 1/1] END max_depth=2, max_features=0.5, n_estimators=100;, score=0.948 total time=   1.1s
# [CV 4/5; 1/1] START max_depth=2, max_features=0.5, n_estimators=100.............
# [CV 4/5; 1/1] END max_depth=2, max_features=0.5, n_estimators=100;, score=0.929 total time=   0.7s
# [CV 5/5; 1/1] START max_depth=2, max_features=0.5, n_estimators=100.............
# [CV 5/5; 1/1] END max_depth=2, max_features=0.5, n_estimators=100;, score=0.943 total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=50.............
# [CV 1/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=50;, score=0.947 total time=   2.2s
# [CV 2/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=50.............
# [CV 2/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=50;, score=0.948 total time=   2.4s
# [CV 3/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=50.............
# [CV 3/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=50;, score=0.957 total time=   3.1s
# [CV 4/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=50.............
# [CV 4/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=50;, score=0.942 total time=   2.2s
# [CV 5/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=50.............
# [CV 5/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=50;, score=0.940 total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=75..............
# [CV 1/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=75;, score=0.947 total time=   0.7s
# [CV 2/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=75..............
# [CV 2/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=75;, score=0.944 total time=   0.7s
# [CV 3/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=75..............
# [CV 3/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=75;, score=0.957 total time=   0.7s
# [CV 4/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=75..............
# [CV 4/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=75;, score=0.935 total time=   0.7s
# [CV 5/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=75..............
# [CV 5/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=75;, score=0.955 total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=150.............
# [CV 1/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=150;, score=0.955 total time=   6.1s
# [CV 2/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=150.............
# [CV 2/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=150;, score=0.952 total time=   5.0s
# [CV 3/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=150.............
# [CV 3/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=150;, score=0.962 total time=   5.4s
# [CV 4/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=150.............
# [CV 4/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=150;, score=0.952 total time=   5.7s
# [CV 5/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=150.............
# [CV 5/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=150;, score=0.959 total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.5, n_estimators=150.............
# [CV 1/5; 1/1] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.952 total time=   2.3s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.5, n_estimators=150.............
# [CV 2/5; 1/1] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.958 total time=   2.8s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.5, n_estimators=150.............
# [CV 3/5; 1/1] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.959 total time=   2.1s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.5, n_estimators=150.............
# [CV 4/5; 1/1] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.947 total time=   2.0s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.5, n_estimators=150.............
# [CV 5/5; 1/1] END max_depth=6, max_features=0.5, n_estimators=150;, score=0.962 total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=50..............
# [CV 1/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=50;, score=0.950 total time=   1.0s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=50..............
# [CV 2/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=50;, score=0.950 total time=   1.0s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=50..............
# [CV 3/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=50;, score=0.958 total time=   1.0s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=50..............
# [CV 4/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=50;, score=0.942 total time=   1.2s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=50..............
# [CV 5/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=50;, score=0.961 total time=   1.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 1/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.952 total time=   2.9s
# [CV 2/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 2/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.950 total time=   2.5s
# [CV 3/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 3/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.959 total time=   2.5s
# [CV 4/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 4/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.947 total time=   2.5s
# [CV 5/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 5/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.958 total time=   3.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=150.............
# [CV 1/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=150;, score=0.952 total time=   2.9s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=150.............
# [CV 2/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=150;, score=0.950 total time=   2.8s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=150.............
# [CV 3/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=150;, score=0.969 total time=   2.9s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=150.............
# [CV 4/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=150;, score=0.946 total time=   3.2s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.5, n_estimators=150.............
# [CV 5/5; 1/1] END max_depth=8, max_features=0.5, n_estimators=150;, score=0.959 total time=   3.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=75..............
# [CV 1/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.947 total time=   1.3s
# [CV 2/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=75..............
# [CV 2/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.940 total time=   1.3s
# [CV 3/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=75..............
# [CV 3/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.955 total time=   1.3s
# [CV 4/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=75..............
# [CV 4/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.938 total time=   1.3s
# [CV 5/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=75..............
# [CV 5/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=75;, score=0.948 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=2, max_features=0.25, n_estimators=50.............
# [CV 1/5; 1/1] END max_depth=2, max_features=0.25, n_estimators=50;, score=0.936 total time=   0.2s
# [CV 2/5; 1/1] START max_depth=2, max_features=0.25, n_estimators=50.............
# [CV 2/5; 1/1] END max_depth=2, max_features=0.25, n_estimators=50;, score=0.912 total time=   0.2s
# [CV 3/5; 1/1] START max_depth=2, max_features=0.25, n_estimators=50.............
# [CV 3/5; 1/1] END max_depth=2, max_features=0.25, n_estimators=50;, score=0.939 total time=   0.2s
# [CV 4/5; 1/1] START max_depth=2, max_features=0.25, n_estimators=50.............
# [CV 4/5; 1/1] END max_depth=2, max_features=0.25, n_estimators=50;, score=0.932 total time=   0.2s
# [CV 5/5; 1/1] START max_depth=2, max_features=0.25, n_estimators=50.............
# [CV 5/5; 1/1] END max_depth=2, max_features=0.25, n_estimators=50;, score=0.921 total time=   0.2s
# Precisión: 95.1% con OrderedDict([('max_depth', 8), ('max_features', 1.0), ('n_estimators', 150)])

# %% [markdown]
# ## HistGradientBoostingClassifier
# Un problema del clasificador GradientBoosting implementado en sklearn es su velocidad. Es un clasificador muy lento de entrenar. Por ello sklearn propone otro tipo de algoritmo de GradientBoosting que soporta paralelismo con OMP además de otras mejoras computacionales basadas en la discretización de las componentes mediante un histograma.
#
# Este otro algoritmo se denomina **HistGradientBoostingClassifier**. Su tiempo de ejecución es mucho mejor. Además se pueden obtener mejores resultados.

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier()

acc=hgb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# Precisión: 95.5%

# %% [markdown]
# **Ejercicio** Analiza en la documentación [HistGradientBoosting](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingClassifier.html) los parámetros más relevantes y realiza una búsqueda de parámetros para obtener el mejor clasificador. A la hora de establecer los valores de los parámetros sería interesante fijarnos en los valores por defecto que se han empleado en el ejercicio anterior y poder explorar alrededor de dichos valores por defecto para conseguir mejores resultados.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier()

## Grid Search
G = {"learning_rate": Real(0.1,1),
     "max_depth":Integer(10,100),
     "max_iter":Integer(80,200),
     "max_bins":Integer(150,250)}

BS = BayesSearchCV(hgb, G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107
# [CV 1/5; 1/1] END learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107;, score=0.952 total time=   7.6s
# [CV 2/5; 1/1] START learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107
# [CV 2/5; 1/1] END learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107;, score=0.962 total time=   1.0s
# [CV 3/5; 1/1] START learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107
# [CV 3/5; 1/1] END learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107;, score=0.974 total time=   1.0s
# [CV 4/5; 1/1] START learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107
# [CV 4/5; 1/1] END learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107;, score=0.954 total time=   0.9s
# [CV 5/5; 1/1] START learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107
# [CV 5/5; 1/1] END learning_rate=0.1342091171568812, max_bins=236, max_depth=49, max_iter=107;, score=0.957 total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103
# [CV 1/5; 1/1] END learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103;, score=0.946 total time=   0.8s
# [CV 2/5; 1/1] START learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103
# [CV 2/5; 1/1] END learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103;, score=0.958 total time=   0.8s
# [CV 3/5; 1/1] START learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103
# [CV 3/5; 1/1] END learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103;, score=0.962 total time=   0.9s
# [CV 4/5; 1/1] START learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103
# [CV 4/5; 1/1] END learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103;, score=0.948 total time=   4.9s
# [CV 5/5; 1/1] START learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103
# [CV 5/5; 1/1] END learning_rate=0.5319574457679351, max_bins=211, max_depth=96, max_iter=103;, score=0.955 total time=   5.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142
# [CV 1/5; 1/1] END learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142;, score=0.946 total time=   2.6s
# [CV 2/5; 1/1] START learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142
# [CV 2/5; 1/1] END learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142;, score=0.959 total time=   3.5s
# [CV 3/5; 1/1] START learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142
# [CV 3/5; 1/1] END learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142;, score=0.971 total time=   9.3s
# [CV 4/5; 1/1] START learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142
# [CV 4/5; 1/1] END learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142;, score=0.948 total time=   2.9s
# [CV 5/5; 1/1] START learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142
# [CV 5/5; 1/1] END learning_rate=0.17499470895793878, max_bins=222, max_depth=62, max_iter=142;, score=0.957 total time=   7.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135
# [CV 1/5; 1/1] END learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135;, score=0.947 total time=   4.0s
# [CV 2/5; 1/1] START learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135
# [CV 2/5; 1/1] END learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135;, score=0.959 total time=   3.0s
# [CV 3/5; 1/1] START learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135
# [CV 3/5; 1/1] END learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135;, score=0.974 total time=   4.7s
# [CV 4/5; 1/1] START learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135
# [CV 4/5; 1/1] END learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135;, score=0.948 total time=   1.2s
# [CV 5/5; 1/1] START learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135
# [CV 5/5; 1/1] END learning_rate=0.10873221941788172, max_bins=224, max_depth=23, max_iter=135;, score=0.957 total time=   8.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144
# [CV 1/5; 1/1] END learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144;, score=0.946 total time=   2.0s
# [CV 2/5; 1/1] START learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144
# [CV 2/5; 1/1] END learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144;, score=0.955 total time=   0.7s
# [CV 3/5; 1/1] START learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144
# [CV 3/5; 1/1] END learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144;, score=0.966 total time=   0.8s
# [CV 4/5; 1/1] START learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144
# [CV 4/5; 1/1] END learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144;, score=0.951 total time=   0.8s
# [CV 5/5; 1/1] START learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144
# [CV 5/5; 1/1] END learning_rate=0.7554394134247536, max_bins=225, max_depth=25, max_iter=144;, score=0.955 total time=   0.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139
# [CV 1/5; 1/1] END learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139;, score=0.951 total time=   1.2s
# [CV 2/5; 1/1] START learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139
# [CV 2/5; 1/1] END learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139;, score=0.958 total time=   1.1s
# [CV 3/5; 1/1] START learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139
# [CV 3/5; 1/1] END learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139;, score=0.966 total time=   1.1s
# [CV 4/5; 1/1] START learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139
# [CV 4/5; 1/1] END learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139;, score=0.947 total time=   1.1s
# [CV 5/5; 1/1] START learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139
# [CV 5/5; 1/1] END learning_rate=0.30128868819531873, max_bins=234, max_depth=14, max_iter=139;, score=0.952 total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144
# [CV 1/5; 1/1] END learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144;, score=0.952 total time=   3.6s
# [CV 2/5; 1/1] START learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144
# [CV 2/5; 1/1] END learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144;, score=0.954 total time=   1.2s
# [CV 3/5; 1/1] START learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144
# [CV 3/5; 1/1] END learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144;, score=0.969 total time=   1.2s
# [CV 4/5; 1/1] START learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144
# [CV 4/5; 1/1] END learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144;, score=0.954 total time=   1.2s
# [CV 5/5; 1/1] START learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144
# [CV 5/5; 1/1] END learning_rate=0.19199669887687526, max_bins=202, max_depth=59, max_iter=144;, score=0.954 total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110
# [CV 1/5; 1/1] END learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110;, score=0.952 total time=   0.9s
# [CV 2/5; 1/1] START learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110
# [CV 2/5; 1/1] END learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110;, score=0.955 total time=   0.9s
# [CV 3/5; 1/1] START learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110
# [CV 3/5; 1/1] END learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110;, score=0.970 total time=   0.9s
# [CV 4/5; 1/1] START learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110
# [CV 4/5; 1/1] END learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110;, score=0.948 total time=   0.9s
# [CV 5/5; 1/1] START learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110
# [CV 5/5; 1/1] END learning_rate=0.15103205509404855, max_bins=214, max_depth=14, max_iter=110;, score=0.952 total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86
# [CV 1/5; 1/1] END learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86;, score=0.947 total time=   0.7s
# [CV 2/5; 1/1] START learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86
# [CV 2/5; 1/1] END learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86;, score=0.963 total time=   2.9s
# [CV 3/5; 1/1] START learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86
# [CV 3/5; 1/1] END learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86;, score=0.958 total time=   0.6s
# [CV 4/5; 1/1] START learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86
# [CV 4/5; 1/1] END learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86;, score=0.947 total time=   0.6s
# [CV 5/5; 1/1] START learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86
# [CV 5/5; 1/1] END learning_rate=0.8298410953037211, max_bins=237, max_depth=19, max_iter=86;, score=0.952 total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175
# [CV 1/5; 1/1] END learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175;, score=0.950 total time=   0.8s
# [CV 2/5; 1/1] START learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175
# [CV 2/5; 1/1] END learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175;, score=0.955 total time=   0.8s
# [CV 3/5; 1/1] START learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175
# [CV 3/5; 1/1] END learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175;, score=0.965 total time=   0.8s
# [CV 4/5; 1/1] START learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175
# [CV 4/5; 1/1] END learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175;, score=0.950 total time=   0.8s
# [CV 5/5; 1/1] START learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175
# [CV 5/5; 1/1] END learning_rate=0.9177747351200848, max_bins=227, max_depth=28, max_iter=175;, score=0.957 total time=   0.7s
# Precisión: 95.8% con OrderedDict([('learning_rate', 0.1342091171568812), ('max_bins', 236), ('max_depth', 49), ('max_iter', 107)])

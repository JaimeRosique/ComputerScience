# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeRosique/ComputerScience/blob/main/Kneighbours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KVecinos en un dataset de detección de spam
#
# Se propone emplear un clasificador basado en distancias sobre el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)

# %% [markdown]
# ## El clasificador por los vecinos más cercanos

# %%
from sklearn.neighbors import KNeighborsClassifier

kv = KNeighborsClassifier()
acc=kv.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 79.5%

# %% [markdown]
# **Ejercicio:** Explora el principal parámetros del KNN (n_neighbors) y realiza una búsqueda mediante alguna técnica de optimización ya vista en la práctica anterior

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.1-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-24.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-24.4.0 scikit-optimize-0.10.1

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

G = {"n_neighbors": Integer(1,15)}

BS = BayesSearchCV(KNeighborsClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc=BS.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=1...............................................
# [CV 1/5; 1/1] END ................n_neighbors=1;, score=0.821 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=1...............................................
# [CV 2/5; 1/1] END ................n_neighbors=1;, score=0.818 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=1...............................................
# [CV 3/5; 1/1] END ................n_neighbors=1;, score=0.829 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=1...............................................
# [CV 4/5; 1/1] END ................n_neighbors=1;, score=0.800 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=1...............................................
# [CV 5/5; 1/1] END ................n_neighbors=1;, score=0.810 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=10..............................................
# [CV 1/5; 1/1] END ...............n_neighbors=10;, score=0.746 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=10..............................................
# [CV 2/5; 1/1] END ...............n_neighbors=10;, score=0.785 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=10..............................................
# [CV 3/5; 1/1] END ...............n_neighbors=10;, score=0.791 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=10..............................................
# [CV 4/5; 1/1] END ...............n_neighbors=10;, score=0.781 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=10..............................................
# [CV 5/5; 1/1] END ...............n_neighbors=10;, score=0.762 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=10..............................................
# [CV 1/5; 1/1] END ...............n_neighbors=10;, score=0.746 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=10..............................................
# [CV 2/5; 1/1] END ...............n_neighbors=10;, score=0.785 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=10..............................................
# [CV 3/5; 1/1] END ...............n_neighbors=10;, score=0.791 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=10..............................................
# [CV 4/5; 1/1] END ...............n_neighbors=10;, score=0.781 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=10..............................................
# [CV 5/5; 1/1] END ...............n_neighbors=10;, score=0.762 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=2...............................................
# [CV 1/5; 1/1] END ................n_neighbors=2;, score=0.789 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=2...............................................
# [CV 2/5; 1/1] END ................n_neighbors=2;, score=0.784 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=2...............................................
# [CV 3/5; 1/1] END ................n_neighbors=2;, score=0.821 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=2...............................................
# [CV 4/5; 1/1] END ................n_neighbors=2;, score=0.766 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=2...............................................
# [CV 5/5; 1/1] END ................n_neighbors=2;, score=0.784 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=6...............................................
# [CV 1/5; 1/1] END ................n_neighbors=6;, score=0.777 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=6...............................................
# [CV 2/5; 1/1] END ................n_neighbors=6;, score=0.787 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=6...............................................
# [CV 3/5; 1/1] END ................n_neighbors=6;, score=0.798 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=6...............................................
# [CV 4/5; 1/1] END ................n_neighbors=6;, score=0.777 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=6...............................................
# [CV 5/5; 1/1] END ................n_neighbors=6;, score=0.753 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=14..............................................
# [CV 1/5; 1/1] END ...............n_neighbors=14;, score=0.746 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=14..............................................
# [CV 2/5; 1/1] END ...............n_neighbors=14;, score=0.770 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=14..............................................
# [CV 3/5; 1/1] END ...............n_neighbors=14;, score=0.787 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=14..............................................
# [CV 4/5; 1/1] END ...............n_neighbors=14;, score=0.765 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=14..............................................
# [CV 5/5; 1/1] END ...............n_neighbors=14;, score=0.766 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=2...............................................
# [CV 1/5; 1/1] END ................n_neighbors=2;, score=0.789 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=2...............................................
# [CV 2/5; 1/1] END ................n_neighbors=2;, score=0.784 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=2...............................................
# [CV 3/5; 1/1] END ................n_neighbors=2;, score=0.821 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=2...............................................
# [CV 4/5; 1/1] END ................n_neighbors=2;, score=0.766 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=2...............................................
# [CV 5/5; 1/1] END ................n_neighbors=2;, score=0.784 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=14..............................................
# [CV 1/5; 1/1] END ...............n_neighbors=14;, score=0.746 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=14..............................................
# [CV 2/5; 1/1] END ...............n_neighbors=14;, score=0.770 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=14..............................................
# [CV 3/5; 1/1] END ...............n_neighbors=14;, score=0.787 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=14..............................................
# [CV 4/5; 1/1] END ...............n_neighbors=14;, score=0.765 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=14..............................................
# [CV 5/5; 1/1] END ...............n_neighbors=14;, score=0.766 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=7...............................................
# [CV 1/5; 1/1] END ................n_neighbors=7;, score=0.761 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=7...............................................
# [CV 2/5; 1/1] END ................n_neighbors=7;, score=0.793 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=7...............................................
# [CV 3/5; 1/1] END ................n_neighbors=7;, score=0.802 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=7...............................................
# [CV 4/5; 1/1] END ................n_neighbors=7;, score=0.773 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=7...............................................
# [CV 5/5; 1/1] END ................n_neighbors=7;, score=0.776 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START n_neighbors=14..............................................
# [CV 1/5; 1/1] END ...............n_neighbors=14;, score=0.746 total time=   0.1s
# [CV 2/5; 1/1] START n_neighbors=14..............................................
# [CV 2/5; 1/1] END ...............n_neighbors=14;, score=0.770 total time=   0.1s
# [CV 3/5; 1/1] START n_neighbors=14..............................................
# [CV 3/5; 1/1] END ...............n_neighbors=14;, score=0.787 total time=   0.1s
# [CV 4/5; 1/1] START n_neighbors=14..............................................
# [CV 4/5; 1/1] END ...............n_neighbors=14;, score=0.765 total time=   0.1s
# [CV 5/5; 1/1] START n_neighbors=14..............................................
# [CV 5/5; 1/1] END ...............n_neighbors=14;, score=0.766 total time=   0.1s
# Precisión: 82.1% con OrderedDict([('n_neighbors', 1)])

# %% [markdown]
# ## Mejoras
#
# La función de distancia empleada por defecto es la distancia euclídea. Dicha distancia requiere un preproceso de las muestras para que tengan una escala similar todas ellas. Además KNN podría beneficiarse de una proyección mediante PCA con el fin de reducir la dimensionalidad.
#
# **Ejercicio:** Implementa un pipeline con la normalización de los datos y un PCA, seguido del KNN. Busca los mejores parámetros. Se podría conseguir una tasa de acierto >90%.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

kv = KNeighborsClassifier()
pca = PCA()
standard = StandardScaler()


pipe = Pipeline(steps=[("standard",standard),("pca", pca), ("kv",kv)])

G = {"pca__n_components": Integer(1,57),
     "kv__n_neighbors": Integer(1,20)}

BS = BayesSearchCV(pipe, G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc=BS.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=12, pca__n_components=51....................
# [CV 1/5; 1/1] END kv__n_neighbors=12, pca__n_components=51;, score=0.886 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=12, pca__n_components=51....................
# [CV 2/5; 1/1] END kv__n_neighbors=12, pca__n_components=51;, score=0.912 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=12, pca__n_components=51....................
# [CV 3/5; 1/1] END kv__n_neighbors=12, pca__n_components=51;, score=0.904 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=12, pca__n_components=51....................
# [CV 4/5; 1/1] END kv__n_neighbors=12, pca__n_components=51;, score=0.887 total time=   0.1s
# [CV 5/5; 1/1] START kv__n_neighbors=12, pca__n_components=51....................
# [CV 5/5; 1/1] END kv__n_neighbors=12, pca__n_components=51;, score=0.902 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=3, pca__n_components=12.....................
# [CV 1/5; 1/1] END kv__n_neighbors=3, pca__n_components=12;, score=0.891 total time=   0.1s
# [CV 2/5; 1/1] START kv__n_neighbors=3, pca__n_components=12.....................
# [CV 2/5; 1/1] END kv__n_neighbors=3, pca__n_components=12;, score=0.923 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=3, pca__n_components=12.....................
# [CV 3/5; 1/1] END kv__n_neighbors=3, pca__n_components=12;, score=0.910 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=3, pca__n_components=12.....................
# [CV 4/5; 1/1] END kv__n_neighbors=3, pca__n_components=12;, score=0.904 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=3, pca__n_components=12.....................
# [CV 5/5; 1/1] END kv__n_neighbors=3, pca__n_components=12;, score=0.914 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=8, pca__n_components=11.....................
# [CV 1/5; 1/1] END kv__n_neighbors=8, pca__n_components=11;, score=0.899 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=8, pca__n_components=11.....................
# [CV 2/5; 1/1] END kv__n_neighbors=8, pca__n_components=11;, score=0.921 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=8, pca__n_components=11.....................
# [CV 3/5; 1/1] END kv__n_neighbors=8, pca__n_components=11;, score=0.916 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=8, pca__n_components=11.....................
# [CV 4/5; 1/1] END kv__n_neighbors=8, pca__n_components=11;, score=0.908 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=8, pca__n_components=11.....................
# [CV 5/5; 1/1] END kv__n_neighbors=8, pca__n_components=11;, score=0.914 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=10, pca__n_components=53....................
# [CV 1/5; 1/1] END kv__n_neighbors=10, pca__n_components=53;, score=0.880 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=10, pca__n_components=53....................
# [CV 2/5; 1/1] END kv__n_neighbors=10, pca__n_components=53;, score=0.899 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=10, pca__n_components=53....................
# [CV 3/5; 1/1] END kv__n_neighbors=10, pca__n_components=53;, score=0.905 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=10, pca__n_components=53....................
# [CV 4/5; 1/1] END kv__n_neighbors=10, pca__n_components=53;, score=0.895 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=10, pca__n_components=53....................
# [CV 5/5; 1/1] END kv__n_neighbors=10, pca__n_components=53;, score=0.910 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=6, pca__n_components=28.....................
# [CV 1/5; 1/1] END kv__n_neighbors=6, pca__n_components=28;, score=0.905 total time=   0.1s
# [CV 2/5; 1/1] START kv__n_neighbors=6, pca__n_components=28.....................
# [CV 2/5; 1/1] END kv__n_neighbors=6, pca__n_components=28;, score=0.908 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=6, pca__n_components=28.....................
# [CV 3/5; 1/1] END kv__n_neighbors=6, pca__n_components=28;, score=0.913 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=6, pca__n_components=28.....................
# [CV 4/5; 1/1] END kv__n_neighbors=6, pca__n_components=28;, score=0.906 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=6, pca__n_components=28.....................
# [CV 5/5; 1/1] END kv__n_neighbors=6, pca__n_components=28;, score=0.931 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=16, pca__n_components=38....................
# [CV 1/5; 1/1] END kv__n_neighbors=16, pca__n_components=38;, score=0.878 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=16, pca__n_components=38....................
# [CV 2/5; 1/1] END kv__n_neighbors=16, pca__n_components=38;, score=0.902 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=16, pca__n_components=38....................
# [CV 3/5; 1/1] END kv__n_neighbors=16, pca__n_components=38;, score=0.910 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=16, pca__n_components=38....................
# [CV 4/5; 1/1] END kv__n_neighbors=16, pca__n_components=38;, score=0.906 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=16, pca__n_components=38....................
# [CV 5/5; 1/1] END kv__n_neighbors=16, pca__n_components=38;, score=0.910 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=17, pca__n_components=48....................
# [CV 1/5; 1/1] END kv__n_neighbors=17, pca__n_components=48;, score=0.880 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=17, pca__n_components=48....................
# [CV 2/5; 1/1] END kv__n_neighbors=17, pca__n_components=48;, score=0.895 total time=   0.1s
# [CV 3/5; 1/1] START kv__n_neighbors=17, pca__n_components=48....................
# [CV 3/5; 1/1] END kv__n_neighbors=17, pca__n_components=48;, score=0.898 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=17, pca__n_components=48....................
# [CV 4/5; 1/1] END kv__n_neighbors=17, pca__n_components=48;, score=0.897 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=17, pca__n_components=48....................
# [CV 5/5; 1/1] END kv__n_neighbors=17, pca__n_components=48;, score=0.910 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=7, pca__n_components=9......................
# [CV 1/5; 1/1] END kv__n_neighbors=7, pca__n_components=9;, score=0.895 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=7, pca__n_components=9......................
# [CV 2/5; 1/1] END kv__n_neighbors=7, pca__n_components=9;, score=0.917 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=7, pca__n_components=9......................
# [CV 3/5; 1/1] END kv__n_neighbors=7, pca__n_components=9;, score=0.913 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=7, pca__n_components=9......................
# [CV 4/5; 1/1] END kv__n_neighbors=7, pca__n_components=9;, score=0.912 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=7, pca__n_components=9......................
# [CV 5/5; 1/1] END kv__n_neighbors=7, pca__n_components=9;, score=0.910 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=20, pca__n_components=44....................
# [CV 1/5; 1/1] END kv__n_neighbors=20, pca__n_components=44;, score=0.868 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=20, pca__n_components=44....................
# [CV 2/5; 1/1] END kv__n_neighbors=20, pca__n_components=44;, score=0.887 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=20, pca__n_components=44....................
# [CV 3/5; 1/1] END kv__n_neighbors=20, pca__n_components=44;, score=0.894 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=20, pca__n_components=44....................
# [CV 4/5; 1/1] END kv__n_neighbors=20, pca__n_components=44;, score=0.886 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=20, pca__n_components=44....................
# [CV 5/5; 1/1] END kv__n_neighbors=20, pca__n_components=44;, score=0.894 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__n_neighbors=6, pca__n_components=8......................
# [CV 1/5; 1/1] END kv__n_neighbors=6, pca__n_components=8;, score=0.876 total time=   0.2s
# [CV 2/5; 1/1] START kv__n_neighbors=6, pca__n_components=8......................
# [CV 2/5; 1/1] END kv__n_neighbors=6, pca__n_components=8;, score=0.910 total time=   0.2s
# [CV 3/5; 1/1] START kv__n_neighbors=6, pca__n_components=8......................
# [CV 3/5; 1/1] END kv__n_neighbors=6, pca__n_components=8;, score=0.914 total time=   0.2s
# [CV 4/5; 1/1] START kv__n_neighbors=6, pca__n_components=8......................
# [CV 4/5; 1/1] END kv__n_neighbors=6, pca__n_components=8;, score=0.890 total time=   0.2s
# [CV 5/5; 1/1] START kv__n_neighbors=6, pca__n_components=8......................
# [CV 5/5; 1/1] END kv__n_neighbors=6, pca__n_components=8;, score=0.901 total time=   0.2s
# Precisión: 90.3% con OrderedDict([('kv__n_neighbors', 6), ('pca__n_components', 28)])

# %% [markdown]
# También podríamos probar diferentes funciones de distancia [sklearn distances](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.distance_metrics.html#sklearn.metrics.pairwise.distance_metrics) a emplear en el parámetro "metric". Así mismo podríamos explorar el parámetro "weights" que pondera el voto de cada vecino de forma diferente según el parámetro escogido.
#
# **Ejercicio:** prueba también diferentes métricas y "weights" junto con todo lo anterior. Emplea el BayessianOpt visto en la práctica anterior.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

kv = KNeighborsClassifier()
pca = PCA()
standard = StandardScaler()


pipe = Pipeline(steps=[("standard",standard),("pca", pca), ("kv",kv)])

G = {"pca__n_components": Integer(1,57),
     "kv__n_neighbors": Integer(1,20),
     "kv__weights": Categorical(['uniform','distance']),
     "kv__metric": Categorical(['euclidean','l1','l2'])}

BS = BayesSearchCV(pipe, G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc=BS.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# (4601, 57)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19;, score=0.898 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19;, score=0.910 total time=   0.2s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19;, score=0.901 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19;, score=0.913 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=8, kv__weights=uniform, pca__n_components=19;, score=0.924 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6;, score=0.883 total time=   0.1s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6;, score=0.923 total time=   0.1s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6;, score=0.925 total time=   0.1s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6;, score=0.909 total time=   0.1s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=6;, score=0.917 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8;, score=0.902 total time=   0.1s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8;, score=0.923 total time=   0.2s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8;, score=0.935 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8;, score=0.912 total time=   0.1s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=8;, score=0.920 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48
# [CV 1/5; 1/1] END kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48;, score=0.901 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48
# [CV 2/5; 1/1] END kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48;, score=0.924 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48
# [CV 3/5; 1/1] END kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48;, score=0.924 total time=   0.4s
# [CV 4/5; 1/1] START kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48
# [CV 4/5; 1/1] END kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48;, score=0.920 total time=   0.5s
# [CV 5/5; 1/1] START kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48
# [CV 5/5; 1/1] END kv__metric=l2, kv__n_neighbors=13, kv__weights=distance, pca__n_components=48;, score=0.931 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37
# [CV 1/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37;, score=0.904 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37
# [CV 2/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37;, score=0.929 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37
# [CV 3/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37;, score=0.938 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37
# [CV 4/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37;, score=0.904 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37
# [CV 5/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=distance, pca__n_components=37;, score=0.931 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7;, score=0.890 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7;, score=0.923 total time=   0.1s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7;, score=0.927 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7;, score=0.902 total time=   0.1s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=9, kv__weights=distance, pca__n_components=7;, score=0.913 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16;, score=0.912 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16;, score=0.925 total time=   0.2s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16;, score=0.929 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16;, score=0.914 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=16, kv__weights=distance, pca__n_components=16;, score=0.943 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49;, score=0.891 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49;, score=0.910 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49;, score=0.924 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49;, score=0.921 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=15, kv__weights=distance, pca__n_components=49;, score=0.917 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18;, score=0.912 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18;, score=0.929 total time=   0.2s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18;, score=0.923 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18;, score=0.920 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=14, kv__weights=distance, pca__n_components=18;, score=0.933 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54
# [CV 1/5; 1/1] END kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54;, score=0.905 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54
# [CV 2/5; 1/1] END kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54;, score=0.921 total time=   0.2s
# [CV 3/5; 1/1] START kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54
# [CV 3/5; 1/1] END kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54;, score=0.924 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54
# [CV 4/5; 1/1] END kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54;, score=0.924 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54
# [CV 5/5; 1/1] END kv__metric=l2, kv__n_neighbors=19, kv__weights=distance, pca__n_components=54;, score=0.925 total time=   0.2s
# Precisión: 92.8% con OrderedDict([('kv__metric', 'l1'), ('kv__n_neighbors', 16), ('kv__weights', 'distance'), ('pca__n_components', 16)])

# %% [markdown]
# ## Olivetti Faces
#
# Prueba ahora el clasificador KNN junto con todos los parámetros y preprocesos que creas convenientes sobre el dataset de reconocimiento facial de Olivetti.

# %%
import warnings; warnings.filterwarnings('ignore');
from sklearn.datasets import fetch_olivetti_faces
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

## Descarga del dataset Olivetti
X, y = fetch_olivetti_faces(return_X_y=True)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

kv = KNeighborsClassifier()
pca = PCA()
standard = StandardScaler()


pipe = Pipeline(steps=[("standard",standard),("pca", pca), ("kv",kv)])

G = {"pca__n_components": Integer(1,57),
     "kv__n_neighbors": Integer(1,20),
     "kv__weights": ['uniform','distance'],
     "kv__metric": ['euclidean','l1','l2']}

BS = BayesSearchCV(pipe, G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc=BS.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56
# [CV 1/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56;, score=0.766 total time=   0.4s
# [CV 2/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56
# [CV 2/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56;, score=0.859 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56
# [CV 3/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56;, score=0.812 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56
# [CV 4/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56;, score=0.719 total time=   0.3s
# [CV 5/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56
# [CV 5/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=4, kv__weights=uniform, pca__n_components=56;, score=0.656 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32;, score=0.844 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32;, score=0.844 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32;, score=0.859 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32;, score=0.797 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=32;, score=0.766 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21
# [CV 1/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21;, score=0.672 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21
# [CV 2/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21;, score=0.703 total time=   0.4s
# [CV 3/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21
# [CV 3/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21;, score=0.625 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21
# [CV 4/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21;, score=0.609 total time=   0.4s
# [CV 5/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21
# [CV 5/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=21;, score=0.562 total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42
# [CV 1/5; 1/1] END kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42;, score=0.844 total time=   0.4s
# [CV 2/5; 1/1] START kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42
# [CV 2/5; 1/1] END kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42;, score=0.922 total time=   0.4s
# [CV 3/5; 1/1] START kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42
# [CV 3/5; 1/1] END kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42;, score=0.922 total time=   0.4s
# [CV 4/5; 1/1] START kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42
# [CV 4/5; 1/1] END kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42;, score=0.891 total time=   0.4s
# [CV 5/5; 1/1] START kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42
# [CV 5/5; 1/1] END kv__metric=l2, kv__n_neighbors=3, kv__weights=distance, pca__n_components=42;, score=0.812 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33;, score=0.859 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33;, score=0.828 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33;, score=0.859 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33;, score=0.797 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=11, kv__weights=distance, pca__n_components=33;, score=0.766 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25
# [CV 1/5; 1/1] END kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25;, score=0.828 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25
# [CV 2/5; 1/1] END kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25;, score=0.891 total time=   0.2s
# [CV 3/5; 1/1] START kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25
# [CV 3/5; 1/1] END kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25;, score=0.859 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25
# [CV 4/5; 1/1] END kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25;, score=0.859 total time=   0.3s
# [CV 5/5; 1/1] START kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25
# [CV 5/5; 1/1] END kv__metric=l2, kv__n_neighbors=4, kv__weights=distance, pca__n_components=25;, score=0.797 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4
# [CV 1/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4;, score=0.594 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4
# [CV 2/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4;, score=0.516 total time=   0.1s
# [CV 3/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4
# [CV 3/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4;, score=0.531 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4
# [CV 4/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4;, score=0.516 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4
# [CV 5/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=13, kv__weights=distance, pca__n_components=4;, score=0.531 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43
# [CV 1/5; 1/1] END kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43;, score=0.812 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43
# [CV 2/5; 1/1] END kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43;, score=0.859 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43
# [CV 3/5; 1/1] END kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43;, score=0.734 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43
# [CV 4/5; 1/1] END kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43;, score=0.719 total time=   0.3s
# [CV 5/5; 1/1] START kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43
# [CV 5/5; 1/1] END kv__metric=l1, kv__n_neighbors=7, kv__weights=uniform, pca__n_components=43;, score=0.703 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3
# [CV 1/5; 1/1] END kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3;, score=0.266 total time=   0.2s
# [CV 2/5; 1/1] START kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3
# [CV 2/5; 1/1] END kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3;, score=0.281 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3
# [CV 3/5; 1/1] END kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3;, score=0.266 total time=   0.2s
# [CV 4/5; 1/1] START kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3
# [CV 4/5; 1/1] END kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3;, score=0.250 total time=   0.2s
# [CV 5/5; 1/1] START kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3
# [CV 5/5; 1/1] END kv__metric=l2, kv__n_neighbors=14, kv__weights=uniform, pca__n_components=3;, score=0.172 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56
# [CV 1/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56;, score=0.859 total time=   0.3s
# [CV 2/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56
# [CV 2/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56;, score=0.906 total time=   0.3s
# [CV 3/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56
# [CV 3/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56;, score=0.922 total time=   0.3s
# [CV 4/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56
# [CV 4/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56;, score=0.891 total time=   0.4s
# [CV 5/5; 1/1] START kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56
# [CV 5/5; 1/1] END kv__metric=euclidean, kv__n_neighbors=3, kv__weights=distance, pca__n_components=56;, score=0.797 total time=   0.3s
# Precisión: 92.5% con OrderedDict([('kv__metric', 'l2'), ('kv__n_neighbors', 3), ('kv__weights', 'distance'), ('pca__n_components', 42)])
